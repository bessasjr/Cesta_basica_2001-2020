# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Lendo o arquivo que contem valores da cesta básica nas capitais brasileiras de todos os meses, entre 2011 e 2020 (Dados do Dieese)

cest = pd.read_excel('Cesta_basica_br.xls')

cest.head(10).T
# Out:
#                                             0        1        2        3  \
# Gasto Mensal - Total da Cesta             NaN  01-2011  02-2011  03-2011
# Unnamed: 1                           Brasília   255.65   250.48   250.35
# Unnamed: 2                       Campo Grande      NaN      NaN      NaN
# Unnamed: 3                             Cuiabá      NaN      NaN      NaN
# Unnamed: 4                            Goiânia   241.59   241.53   242.55
# Unnamed: 5                     Belo Horizonte   244.12   246.63   248.77
# Unnamed: 6                     Rio de Janeiro   252.24   249.02    259.8
# Unnamed: 7                          São Paulo   261.25   261.18   267.58
# Unnamed: 8                            Vitória   250.26   246.31   258.32
# Unnamed: 9                           Curitiba   237.17   245.15   248.42
# Unnamed: 10                     Florianópolis   246.58   241.47   250.28
# Unnamed: 11                      Porto Alegre    254.7   256.51   261.13
# Unnamed: 12                             Belém   228.55   228.94   232.76
# Unnamed: 13                         Boa Vista      NaN      NaN      NaN
# Unnamed: 14                            Macapá      NaN      NaN      NaN
# Unnamed: 15                            Manaus    255.8   252.75   251.38
# Unnamed: 16                            Palmas      NaN      NaN      NaN
# Unnamed: 17                       Porto Velho      NaN      NaN      NaN
# Unnamed: 18                        Rio Branco      NaN      NaN      NaN
# Unnamed: 19                           Aracaju   182.76   190.66   192.35
# Unnamed: 20                         Fortaleza   216.45   213.75   218.89
# Unnamed: 21                       João Pessoa   200.21   203.26   203.94
# Unnamed: 22                            Maceió      NaN      NaN      NaN
# Unnamed: 23                             Natal   224.58   221.15   234.85
# Unnamed: 24                            Recife   204.85    211.4   209.77
# Unnamed: 25                          Salvador   209.49   210.44   220.75
# Unnamed: 26                          São Luís      NaN      NaN      NaN
# Unnamed: 27                          Teresina      NaN      NaN      NaN
#
#                                      4        5        6        7        8  \
# Gasto Mensal - Total da Cesta  04-2011  05-2011  06-2011  07-2011  08-2011
# Unnamed: 1                      248.32   248.93    246.1   241.89   244.24
# Unnamed: 2                         NaN      NaN      NaN      NaN      NaN
# Unnamed: 3                         NaN      NaN      NaN      NaN      NaN
# Unnamed: 4                      237.16   240.35   232.58   229.38   227.21
# Unnamed: 5                      247.03   247.23   248.06   245.09   249.48
# Unnamed: 6                      255.16      260   256.91   241.47    253.1
# Unnamed: 7                      268.52   272.98   273.48   263.38   266.75
# Unnamed: 8                      256.12   260.59   256.14   250.76   249.58
# Unnamed: 9                      246.53   245.98   247.03   238.77      244
# Unnamed: 10                     252.55   255.12   266.44   254.84      260
# Unnamed: 11                     264.63    265.7   272.24    259.6   271.25
# Unnamed: 12                      231.4   229.62   232.63   233.14   235.66
# Unnamed: 13                        NaN      NaN      NaN      NaN      NaN
# Unnamed: 14                        NaN      NaN      NaN      NaN      NaN
# Unnamed: 15                     247.92   245.54    250.3   249.49    248.1
# Unnamed: 16                        NaN      NaN      NaN      NaN      NaN
# Unnamed: 17                        NaN      NaN      NaN      NaN      NaN
# Unnamed: 18                        NaN      NaN      NaN      NaN      NaN
# Unnamed: 19                     185.88   186.67   183.24   184.01   187.73
# Unnamed: 20                     212.62   218.01   225.94   214.71   206.13
# Unnamed: 21                     198.79   200.18   206.22    204.4   202.47
# Unnamed: 22                        NaN      NaN      NaN      NaN      NaN
# Unnamed: 23                     229.39   225.28   230.97   223.31   219.52
# Unnamed: 24                     202.03   207.66   213.64   212.55   211.09
# Unnamed: 25                     203.38    202.4   204.69   206.58   209.35
# Unnamed: 26                        NaN      NaN      NaN      NaN      NaN
# Unnamed: 27                        NaN      NaN      NaN      NaN      NaN
#
#                                      9
# Gasto Mensal - Total da Cesta  09-2011
# Unnamed: 1                       241.9
# Unnamed: 2                         NaN
# Unnamed: 3                         NaN
# Unnamed: 4                      231.46
# Unnamed: 5                      250.96
# Unnamed: 6                      250.81
# Unnamed: 7                      267.19
# Unnamed: 8                       249.6
# Unnamed: 9                      242.07
# Unnamed: 10                     260.33
# Unnamed: 11                     272.09
# Unnamed: 12                     235.75
# Unnamed: 13                        NaN
# Unnamed: 14                        NaN
# Unnamed: 15                     249.38
# Unnamed: 16                        NaN
# Unnamed: 17                        NaN
# Unnamed: 18                        NaN
# Unnamed: 19                     183.61
# Unnamed: 20                      203.2
# Unnamed: 21                     196.69
# Unnamed: 22                        NaN
# Unnamed: 23                     205.97
# Unnamed: 24                     208.51
# Unnamed: 25                     208.07
# Unnamed: 26                        NaN
# Unnamed: 27                        NaN

# %%
# Modificando o nome nan na linha 0 coluna 0 para Data

cest[['Gasto Mensal - Total da Cesta']] = cest[['Gasto Mensal - Total da Cesta']].fillna('Data')

cest
# Out:
#                          Gasto Mensal - Total da Cesta Unnamed: 1  \
# 0                                                 Data   Brasília
# 1                                              01-2011     255.65
# 2                                              02-2011     250.48
# 3                                              03-2011     250.35
# 4                                              04-2011     248.32
# ..                                                 ...        ...
# 119                                            11-2020     572.64
# 120                                            12-2020     591.82
# 121                                      Fonte: DIEESE        NaN
# 122  (1) Série recalculada, conforme mudança metodo...        NaN
# 123  Tomada especial de preços a partir de abril de...        NaN
#
#        Unnamed: 2 Unnamed: 3 Unnamed: 4      Unnamed: 5      Unnamed: 6  \
# 0    Campo Grande     Cuiabá    Goiânia  Belo Horizonte  Rio de Janeiro
# 1             NaN        NaN     241.59          244.12          252.24
# 2             NaN        NaN     241.53          246.63          249.02
# 3             NaN        NaN     242.55          248.77           259.8
# 4             NaN        NaN     237.16          247.03          255.16
# ..            ...        ...        ...             ...             ...
# 119        589.08        NaN     557.46          552.37          629.63
# 120        576.48        NaN      563.8          568.53          621.09
# 121           NaN        NaN        NaN             NaN             NaN
# 122           NaN        NaN        NaN             NaN             NaN
# 123           NaN        NaN        NaN             NaN             NaN
#
#     Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 18 Unnamed: 19 Unnamed: 20  \
# 0    São Paulo    Vitória   Curitiba  ...  Rio Branco     Aracaju   Fortaleza
# 1       261.25     250.26     237.17  ...         NaN      182.76      216.45
# 2       261.18     246.31     245.15  ...         NaN      190.66      213.75
# 3       267.58     258.32     248.42  ...         NaN      192.35      218.89
# 4       268.52     256.12     246.53  ...         NaN      185.88      212.62
# ..         ...        ...        ...  ...         ...         ...         ...
# 119     629.18     606.59     547.29  ...         NaN      451.32      539.33
# 120     631.46     600.28     540.36  ...         NaN      453.16      534.96
# 121        NaN        NaN        NaN  ...         NaN         NaN         NaN
# 122        NaN        NaN        NaN  ...         NaN         NaN         NaN
# 123        NaN        NaN        NaN  ...         NaN         NaN         NaN
#
#      Unnamed: 21 Unnamed: 22 Unnamed: 23 Unnamed: 24 Unnamed: 25 Unnamed: 26  \
# 0    João Pessoa      Maceió       Natal      Recife    Salvador    São Luís
# 1         200.21         NaN      224.58      204.85      209.49         NaN
# 2         203.26         NaN      221.15       211.4      210.44         NaN
# 3         203.94         NaN      234.85      209.77      220.75         NaN
# 4         198.79         NaN      229.39      202.03      203.38         NaN
# ..           ...         ...         ...         ...         ...         ...
# 119       454.85         NaN      455.43      462.98       488.1         NaN
# 120       475.19         NaN      458.79      469.39      479.08         NaN
# 121          NaN         NaN         NaN         NaN         NaN         NaN
# 122          NaN         NaN         NaN         NaN         NaN         NaN
# 123          NaN         NaN         NaN         NaN         NaN         NaN
#
#     Unnamed: 27
# 0      Teresina
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# ..          ...
# 119         NaN
# 120         NaN
# 121         NaN
# 122         NaN
# 123         NaN
#
# [124 rows x 28 columns]

# %%
# transformando a primeira linha (que contem os estados) em colunas

cest.columns = cest.iloc[0]
cest
# Out:
# 0                                                 Data  Brasília  \
# 0                                                 Data  Brasília
# 1                                              01-2011    255.65
# 2                                              02-2011    250.48
# 3                                              03-2011    250.35
# 4                                              04-2011    248.32
# ..                                                 ...       ...
# 119                                            11-2020    572.64
# 120                                            12-2020    591.82
# 121                                      Fonte: DIEESE       NaN
# 122  (1) Série recalculada, conforme mudança metodo...       NaN
# 123  Tomada especial de preços a partir de abril de...       NaN
#
# 0    Campo Grande  Cuiabá  Goiânia  Belo Horizonte  Rio de Janeiro  São Paulo  \
# 0    Campo Grande  Cuiabá  Goiânia  Belo Horizonte  Rio de Janeiro  São Paulo
# 1             NaN     NaN   241.59          244.12          252.24     261.25
# 2             NaN     NaN   241.53          246.63          249.02     261.18
# 3             NaN     NaN   242.55          248.77           259.8     267.58
# 4             NaN     NaN   237.16          247.03          255.16     268.52
# ..            ...     ...      ...             ...             ...        ...
# 119        589.08     NaN   557.46          552.37          629.63     629.18
# 120        576.48     NaN    563.8          568.53          621.09     631.46
# 121           NaN     NaN      NaN             NaN             NaN        NaN
# 122           NaN     NaN      NaN             NaN             NaN        NaN
# 123           NaN     NaN      NaN             NaN             NaN        NaN
#
# 0    Vitória  Curitiba  ...  Rio Branco  Aracaju  Fortaleza  João Pessoa  \
# 0    Vitória  Curitiba  ...  Rio Branco  Aracaju  Fortaleza  João Pessoa
# 1     250.26    237.17  ...         NaN   182.76     216.45       200.21
# 2     246.31    245.15  ...         NaN   190.66     213.75       203.26
# 3     258.32    248.42  ...         NaN   192.35     218.89       203.94
# 4     256.12    246.53  ...         NaN   185.88     212.62       198.79
# ..       ...       ...  ...         ...      ...        ...          ...
# 119   606.59    547.29  ...         NaN   451.32     539.33       454.85
# 120   600.28    540.36  ...         NaN   453.16     534.96       475.19
# 121      NaN       NaN  ...         NaN      NaN        NaN          NaN
# 122      NaN       NaN  ...         NaN      NaN        NaN          NaN
# 123      NaN       NaN  ...         NaN      NaN        NaN          NaN
#
# 0    Maceió   Natal  Recife  Salvador  São Luís  Teresina
# 0    Maceió   Natal  Recife  Salvador  São Luís  Teresina
# 1       NaN  224.58  204.85    209.49       NaN       NaN
# 2       NaN  221.15   211.4    210.44       NaN       NaN
# 3       NaN  234.85  209.77    220.75       NaN       NaN
# 4       NaN  229.39  202.03    203.38       NaN       NaN
# ..      ...     ...     ...       ...       ...       ...
# 119     NaN  455.43  462.98     488.1       NaN       NaN
# 120     NaN  458.79  469.39    479.08       NaN       NaN
# 121     NaN     NaN     NaN       NaN       NaN       NaN
# 122     NaN     NaN     NaN       NaN       NaN       NaN
# 123     NaN     NaN     NaN       NaN       NaN       NaN
#
# [124 rows x 28 columns]

# %%
# Deletando a primeira linha(já transformada em colunas)

cest = cest.drop(index=[0])
cest
# Out:
# 0                                                 Data Brasília Campo Grande  \
# 1                                              01-2011   255.65          NaN
# 2                                              02-2011   250.48          NaN
# 3                                              03-2011   250.35          NaN
# 4                                              04-2011   248.32          NaN
# 5                                              05-2011   248.93          NaN
# ..                                                 ...      ...          ...
# 119                                            11-2020   572.64       589.08
# 120                                            12-2020   591.82       576.48
# 121                                      Fonte: DIEESE      NaN          NaN
# 122  (1) Série recalculada, conforme mudança metodo...      NaN          NaN
# 123  Tomada especial de preços a partir de abril de...      NaN          NaN
#
# 0   Cuiabá Goiânia Belo Horizonte Rio de Janeiro São Paulo Vitória Curitiba  \
# 1      NaN  241.59         244.12         252.24    261.25  250.26   237.17
# 2      NaN  241.53         246.63         249.02    261.18  246.31   245.15
# 3      NaN  242.55         248.77          259.8    267.58  258.32   248.42
# 4      NaN  237.16         247.03         255.16    268.52  256.12   246.53
# 5      NaN  240.35         247.23            260    272.98  260.59   245.98
# ..     ...     ...            ...            ...       ...     ...      ...
# 119    NaN  557.46         552.37         629.63    629.18  606.59   547.29
# 120    NaN   563.8         568.53         621.09    631.46  600.28   540.36
# 121    NaN     NaN            NaN            NaN       NaN     NaN      NaN
# 122    NaN     NaN            NaN            NaN       NaN     NaN      NaN
# 123    NaN     NaN            NaN            NaN       NaN     NaN      NaN
#
# 0    ... Rio Branco Aracaju Fortaleza João Pessoa Maceió   Natal  Recife  \
# 1    ...        NaN  182.76    216.45      200.21    NaN  224.58  204.85
# 2    ...        NaN  190.66    213.75      203.26    NaN  221.15   211.4
# 3    ...        NaN  192.35    218.89      203.94    NaN  234.85  209.77
# 4    ...        NaN  185.88    212.62      198.79    NaN  229.39  202.03
# 5    ...        NaN  186.67    218.01      200.18    NaN  225.28  207.66
# ..   ...        ...     ...       ...         ...    ...     ...     ...
# 119  ...        NaN  451.32    539.33      454.85    NaN  455.43  462.98
# 120  ...        NaN  453.16    534.96      475.19    NaN  458.79  469.39
# 121  ...        NaN     NaN       NaN         NaN    NaN     NaN     NaN
# 122  ...        NaN     NaN       NaN         NaN    NaN     NaN     NaN
# 123  ...        NaN     NaN       NaN         NaN    NaN     NaN     NaN
#
# 0   Salvador São Luís Teresina
# 1     209.49      NaN      NaN
# 2     210.44      NaN      NaN
# 3     220.75      NaN      NaN
# 4     203.38      NaN      NaN
# 5      202.4      NaN      NaN
# ..       ...      ...      ...
# 119    488.1      NaN      NaN
# 120   479.08      NaN      NaN
# 121      NaN      NaN      NaN
# 122      NaN      NaN      NaN
# 123      NaN      NaN      NaN
#
# [123 rows x 28 columns]

# %%
# Deletando as 3 ultimas linhas (que não contém mais dados)

cest = cest.iloc[:120]
cest
# Out:
# 0       Data Brasília Campo Grande Cuiabá Goiânia Belo Horizonte  \
# 1    01-2011   255.65          NaN    NaN  241.59         244.12
# 2    02-2011   250.48          NaN    NaN  241.53         246.63
# 3    03-2011   250.35          NaN    NaN  242.55         248.77
# 4    04-2011   248.32          NaN    NaN  237.16         247.03
# 5    05-2011   248.93          NaN    NaN  240.35         247.23
# ..       ...      ...          ...    ...     ...            ...
# 116  08-2020   443.28       484.46    NaN  483.15         478.07
# 117  09-2020   445.76        492.8    NaN  510.52         491.62
# 118  10-2020   490.48       520.12    NaN  537.61         516.82
# 119  11-2020   572.64       589.08    NaN  557.46         552.37
# 120  12-2020   591.82       576.48    NaN   563.8         568.53
#
# 0   Rio de Janeiro São Paulo Vitória Curitiba  ... Rio Branco Aracaju  \
# 1           252.24    261.25  250.26   237.17  ...        NaN  182.76
# 2           249.02    261.18  246.31   245.15  ...        NaN  190.66
# 3            259.8    267.58  258.32   248.42  ...        NaN  192.35
# 4           255.16    268.52  256.12   246.53  ...        NaN  185.88
# 5              260    272.98  260.59   245.98  ...        NaN  186.67
# ..             ...       ...     ...      ...  ...        ...     ...
# 116         529.76    539.95  509.45   505.54  ...        NaN  398.47
# 117         563.75    563.35  539.36   524.25  ...        NaN  427.11
# 118         592.25    595.87  552.85   521.12  ...        NaN  442.26
# 119         629.63    629.18  606.59   547.29  ...        NaN  451.32
# 120         621.09    631.46  600.28   540.36  ...        NaN  453.16
#
# 0   Fortaleza João Pessoa Maceió   Natal  Recife Salvador São Luís Teresina
# 1      216.45      200.21    NaN  224.58  204.85   209.49      NaN      NaN
# 2      213.75      203.26    NaN  221.15   211.4   210.44      NaN      NaN
# 3      218.89      203.94    NaN  234.85  209.77   220.75      NaN      NaN
# 4      212.62      198.79    NaN  229.39  202.03   203.38      NaN      NaN
# 5      218.01      200.18    NaN  225.28  207.66    202.4      NaN      NaN
# ..        ...         ...    ...     ...     ...      ...      ...      ...
# 116    462.13       414.5    NaN  419.47  439.19   418.72      NaN      NaN
# 117    485.75      432.04    NaN  422.31  464.31   459.33      NaN      NaN
# 118    510.54      449.97    NaN  436.76  469.05    454.5      NaN      NaN
# 119    539.33      454.85    NaN  455.43  462.98    488.1      NaN      NaN
# 120    534.96      475.19    NaN  458.79  469.39   479.08      NaN      NaN
#
# [120 rows x 28 columns]

# %%
# Descobrindo a média anual do valor da cesta básica por capital e salvando em um dicionário

anos = ['2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020']

lista_mes = []
lista_ano = []

dic = {}

for s in cest.columns[1:]:
    for p in anos:
        for n in range(len(cest['Data'])):
            if cest['Data'][n+1][3:] == p:
                if cest[s][n+1] > 0:
                    lista_mes.append(cest[s][n+1])
                if len(lista_mes) > 0:
                    h = round((sum(lista_mes)/len(lista_mes)), 2)
                else:
                    h = None
        lista_mes.clear()
        lista_ano.append(h)

    dic[s] = lista_ano[0:10]
    lista_ano.clear()

print(dic)
# Out:
# {'Brasília': [247.33, 266.16, 296.39, 313.48, 358.85, 443.4, 404.45, 407.59, 452.49, 483.81], 'Campo Grande': [None, 266.1, 295.3, 304.07, 347.01, 416.8, 379.21, 387.98, 429.37, 495.56], 'Cuiabá': [None, None, None, None, 390.88, 428.0, 389.34, 397.92, None, None], 'Goiânia': [236.47, 248.89, 275.6, 288.82, 325.39, 393.37, 379.81, 365.21, 416.85, 497.1], 'Belo Horizonte': [250.02, 276.45, 307.57, 314.78, 346.46, 412.39, 376.13, 377.42, 418.51, 491.08], 'Rio de Janeiro': [254.59, 276.2, 310.39, 332.72, 370.58, 444.41, 425.07, 440.26, 480.25, 550.38], 'São Paulo': [268.57, 292.84, 328.43, 344.9, 389.65, 456.48, 434.87, 444.49, 490.36, 558.33], 'Vitória': [255.75, 281.64, 317.53, 335.93, 367.66, 428.52, 406.35, 408.54, 462.11, 528.75], 'Curitiba': [245.24, 264.13, 291.92, 315.72, 358.31, 412.94, 390.15, 400.64, 435.29, 506.58], 'Florianópolis': [256.63, 273.81, 300.8, 344.67, 379.52, 448.01, 431.46, 435.09, 472.48, 543.03], 'Porto Alegre': [267.64, 286.32, 318.8, 340.52, 381.6, 452.73, 445.72, 441.02, 475.76, 538.21], 'Belém': [234.41, 257.47, 296.43, 305.44, 329.66, 412.01, 383.91, 368.83, 398.19, 450.5], 'Boa Vista': [None, None, None, None, 363.9, 411.22, 378.69, None, None, None], 'Macapá': [None, None, None, None, 341.77, 380.97, 365.01, None, None, None], 'Manaus': [251.36, 275.31, 313.3, 314.02, 339.91, 398.77, 364.78, 359.18, None, None], 'Palmas': [None, None, None, None, 346.02, 389.13, 374.65, None, None, None], 'Porto Velho': [None, None, None, None, 347.47, 376.77, 378.14, None, None, None], 'Rio Branco': [None, None, None, None, 310.96, 361.43, 331.54, None, None, None], 'Aracaju': [185.3, 200.42, 233.66, 234.72, 280.5, 362.55, 353.17, 346.31, 362.23, 409.73], 'Fortaleza': [212.5, 235.0, 274.81, 283.59, 316.17, 394.6, 393.23, 387.99, 421.25, 480.07], 'João Pessoa': [201.15, 226.48, 269.32, 268.17, 301.1, 369.82, 356.34, 344.59, 378.26, 429.91], 'Maceió': [None, None, None, None, 324.44, 372.68, 366.87, None, None, None], 'Natal': [219.49, 233.69, 274.92, 273.62, 294.59, 348.35, 346.35, 341.1, 375.14, 428.74], 'Recife': [209.51, 235.52, 278.03, 287.7, 309.44, 359.55, 348.79, 342.08, 381.29, 444.88], 'Salvador': [207.85, 218.53, 263.35, 267.79, 312.64, 360.66, 340.48, 327.82, 365.9, 429.13], 'São Luís': [None, None, None, None, 327.49, 368.04, 352.63, 345.9, 385.48, None], 'Teresina': [None, None, None, None, 343.59, 387.36, 387.92, None, None, None]}

# %%
# Criando o Dataframe que contem a média anual dos valores da cesta básica nas capitais brasileiras

cesta = pd.DataFrame(dic, index=[2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020])

cesta
# Out:
#       Brasília  Campo Grande  Cuiabá  Goiânia  Belo Horizonte  Rio de Janeiro  \
# 2011    247.33           NaN     NaN   236.47          250.02          254.59
# 2012    266.16        266.10     NaN   248.89          276.45          276.20
# 2013    296.39        295.30     NaN   275.60          307.57          310.39
# 2014    313.48        304.07     NaN   288.82          314.78          332.72
# 2015    358.85        347.01  390.88   325.39          346.46          370.58
# 2016    443.40        416.80  428.00   393.37          412.39          444.41
# 2017    404.45        379.21  389.34   379.81          376.13          425.07
# 2018    407.59        387.98  397.92   365.21          377.42          440.26
# 2019    452.49        429.37     NaN   416.85          418.51          480.25
# 2020    483.81        495.56     NaN   497.10          491.08          550.38
#
#       São Paulo  Vitória  Curitiba  Florianópolis  ...  Rio Branco  Aracaju  \
# 2011     268.57   255.75    245.24         256.63  ...         NaN   185.30
# 2012     292.84   281.64    264.13         273.81  ...         NaN   200.42
# 2013     328.43   317.53    291.92         300.80  ...         NaN   233.66
# 2014     344.90   335.93    315.72         344.67  ...         NaN   234.72
# 2015     389.65   367.66    358.31         379.52  ...      310.96   280.50
# 2016     456.48   428.52    412.94         448.01  ...      361.43   362.55
# 2017     434.87   406.35    390.15         431.46  ...      331.54   353.17
# 2018     444.49   408.54    400.64         435.09  ...         NaN   346.31
# 2019     490.36   462.11    435.29         472.48  ...         NaN   362.23
# 2020     558.33   528.75    506.58         543.03  ...         NaN   409.73
#
#       Fortaleza  João Pessoa  Maceió   Natal  Recife  Salvador  São Luís  \
# 2011     212.50       201.15     NaN  219.49  209.51    207.85       NaN
# 2012     235.00       226.48     NaN  233.69  235.52    218.53       NaN
# 2013     274.81       269.32     NaN  274.92  278.03    263.35       NaN
# 2014     283.59       268.17     NaN  273.62  287.70    267.79       NaN
# 2015     316.17       301.10  324.44  294.59  309.44    312.64    327.49
# 2016     394.60       369.82  372.68  348.35  359.55    360.66    368.04
# 2017     393.23       356.34  366.87  346.35  348.79    340.48    352.63
# 2018     387.99       344.59     NaN  341.10  342.08    327.82    345.90
# 2019     421.25       378.26     NaN  375.14  381.29    365.90    385.48
# 2020     480.07       429.91     NaN  428.74  444.88    429.13       NaN
#
#       Teresina
# 2011       NaN
# 2012       NaN
# 2013       NaN
# 2014       NaN
# 2015    343.59
# 2016    387.36
# 2017    387.92
# 2018       NaN
# 2019       NaN
# 2020       NaN
#
# [10 rows x 27 columns]

# %%
# Excluindo as cidades que não tem dados em todos os anos analizados

cesta = cesta.dropna(axis=1)
cesta
# Out:
#       Brasília  Goiânia  Belo Horizonte  Rio de Janeiro  São Paulo  Vitória  \
# 2011    247.33   236.47          250.02          254.59     268.57   255.75
# 2012    266.16   248.89          276.45          276.20     292.84   281.64
# 2013    296.39   275.60          307.57          310.39     328.43   317.53
# 2014    313.48   288.82          314.78          332.72     344.90   335.93
# 2015    358.85   325.39          346.46          370.58     389.65   367.66
# 2016    443.40   393.37          412.39          444.41     456.48   428.52
# 2017    404.45   379.81          376.13          425.07     434.87   406.35
# 2018    407.59   365.21          377.42          440.26     444.49   408.54
# 2019    452.49   416.85          418.51          480.25     490.36   462.11
# 2020    483.81   497.10          491.08          550.38     558.33   528.75
#
#       Curitiba  Florianópolis  Porto Alegre   Belém  Aracaju  Fortaleza  \
# 2011    245.24         256.63        267.64  234.41   185.30     212.50
# 2012    264.13         273.81        286.32  257.47   200.42     235.00
# 2013    291.92         300.80        318.80  296.43   233.66     274.81
# 2014    315.72         344.67        340.52  305.44   234.72     283.59
# 2015    358.31         379.52        381.60  329.66   280.50     316.17
# 2016    412.94         448.01        452.73  412.01   362.55     394.60
# 2017    390.15         431.46        445.72  383.91   353.17     393.23
# 2018    400.64         435.09        441.02  368.83   346.31     387.99
# 2019    435.29         472.48        475.76  398.19   362.23     421.25
# 2020    506.58         543.03        538.21  450.50   409.73     480.07
#
#       João Pessoa   Natal  Recife  Salvador
# 2011       201.15  219.49  209.51    207.85
# 2012       226.48  233.69  235.52    218.53
# 2013       269.32  274.92  278.03    263.35
# 2014       268.17  273.62  287.70    267.79
# 2015       301.10  294.59  309.44    312.64
# 2016       369.82  348.35  359.55    360.66
# 2017       356.34  346.35  348.79    340.48
# 2018       344.59  341.10  342.08    327.82
# 2019       378.26  375.14  381.29    365.90
# 2020       429.91  428.74  444.88    429.13

# %%
cesta.index[1:2]
# Out:
# Int64Index([2012], dtype='int64')

# %%
# Descobrindo a variação anual da cesta básica em cada capital analisada

mes_a_mes = []
mes_1 = []
percentual_mes_a_mes = {}

# Calculando todos os resultados e colocando em uma lista
for i in cesta.columns:
    for p in cesta.index[1:]:
        n = ((cesta[i][p] / cesta[i][p-1]) - 1) * 100
        mes_1.append(n)

# Separando a lista pela quantidade de dados e salvando em uma nova lista separada
n = 9
for s in range(0, len(mes_1), 9):    
    mes_a_mes.append(mes_1[s:s + n])
    
# Passando os dados da lista para um dicionário    
for i in range(0, len(cesta.columns)):
    percentual_mes_a_mes[cesta.columns[i]] = mes_a_mes[i]


percentual_mes_a_mes
# Out:
# {'Brasília': [7.613310152427943,
#   11.357829876765834,
#   5.766051486217494,
#   14.473012632384851,
#   23.561376619757546,
#   -8.784393324312134,
#   0.7763629620472168,
#   11.015971932579326,
#   6.921699927070213],
#  'Goiânia': [5.252251871273317,
#   10.731648519426273,
#   4.796806966618283,
#   12.66186552177826,
#   20.891852853498882,
#   -3.4471362839057385,
#   -3.8440272767963024,
#   14.139809972344697,
#   19.251529327096083],
#  'Belo Horizonte': [10.571154307655384,
#   11.257008500633026,
#   2.344181812270363,
#   10.064171802528744,
#   19.029613808231826,
#   -8.792647736366055,
#   0.34296652753038614,
#   10.887075406708702,
#   17.340087453107444],
#  'Rio de Janeiro': [8.488157429592679,
#   12.378711078928317,
#   7.194175070073139,
#   11.378937244529919,
#   19.92282368179612,
#   -4.351837267388225,
#   3.573529065800929,
#   9.083268977422442,
#   14.602811035918783],
#  'São Paulo': [9.036750195479758,
#   12.15339434503484,
#   5.014767225892869,
#   12.974775297187602,
#   17.151289618888764,
#   -4.73405187521907,
#   2.212155356773282,
#   10.319692231546274,
#   13.86124479973898],
#  'Vitória': [10.123167155425206,
#   12.743218292856117,
#   5.794728057191456,
#   9.44542017682255,
#   16.55333732252624,
#   -5.1736208345001256,
#   0.5389442598744854,
#   13.112547119009154,
#   14.420808898314252],
#  'Curitiba': [7.702658620127223,
#   10.521334191496612,
#   8.152918607837778,
#   13.489801089573028,
#   15.246574195529018,
#   -5.518961592483174,
#   2.6887094707163994,
#   8.648662140575091,
#   16.377587355556056],
#  'Florianópolis': [6.694462845341542,
#   9.857200248347397,
#   14.58444148936171,
#   10.111120782197446,
#   18.046479763912316,
#   -3.6941139706702986,
#   0.841329439577243,
#   8.593624307614522,
#   14.931848967152028],
#  'Porto Alegre': [6.979524734718279,
#   11.343950824252591,
#   6.8130489335006095,
#   12.063902267120884,
#   18.639937106918246,
#   -1.5483842466812447,
#   -1.0544736605941019,
#   7.877193778059954,
#   13.126366235076524],
#  'Belém': [9.83746427200205,
#   15.131860022526888,
#   3.0395034240798813,
#   7.929544264012578,
#   24.98028271552508,
#   -6.820222810125964,
#   -3.9280039592612948,
#   7.960306916465587,
#   13.136944674652806],
#  'Aracaju': [8.159740960604411,
#   16.585171140604736,
#   0.4536506034408916,
#   19.50408997955011,
#   29.25133689839572,
#   -2.5872293476761787,
#   -1.9424073392417252,
#   4.597037336490439,
#   13.113215360406372],
#  'Fortaleza': [10.588235294117654,
#   16.940425531914904,
#   3.194934682144024,
#   11.48841637575375,
#   24.806275105164953,
#   -0.34718702483528263,
#   -1.3325534674363593,
#   8.57238588623417,
#   13.963204747774483],
#  'João Pessoa': [12.592592592592577,
#   18.915577534440132,
#   -0.4270013366998282,
#   12.279524182421596,
#   22.82298239787446,
#   -3.6450164945108443,
#   -3.29741258348768,
#   9.771032241214206,
#   13.654629091101377],
#  'Natal': [6.469543031573188,
#   17.643031366340022,
#   -0.47286483340608365,
#   7.663913456618654,
#   18.249091958314967,
#   -0.5741352088416862,
#   -1.5158077089649225,
#   9.979478158897681,
#   14.28799914698513],
#  'Recife': [12.41468187676007,
#   18.049422554347807,
#   3.478041937920384,
#   7.556482446993407,
#   16.193769389865565,
#   -2.992629675983871,
#   -1.9237936867456118,
#   11.462231057062677,
#   16.677594481890413],
#  'Salvador': [5.138320904498439,
#   20.509769825653244,
#   1.6859692424530115,
#   16.74819821501923,
#   15.359518935516903,
#   -5.595297510120334,
#   -3.718280075187974,
#   11.61613080348971,
#   17.280677780814436]}

# %%
# Criando um Dataframe com os dados da variação anual de cada cidade analisada

cesta_evolucao_perc = pd.DataFrame(percentual_mes_a_mes,index=[2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020], columns=percentual_mes_a_mes.keys())

cesta_evolucao_perc
# Out:
#        Brasília    Goiânia  Belo Horizonte  Rio de Janeiro  São Paulo  \
# 2012   7.613310   5.252252       10.571154        8.488157   9.036750
# 2013  11.357830  10.731649       11.257009       12.378711  12.153394
# 2014   5.766051   4.796807        2.344182        7.194175   5.014767
# 2015  14.473013  12.661866       10.064172       11.378937  12.974775
# 2016  23.561377  20.891853       19.029614       19.922824  17.151290
# 2017  -8.784393  -3.447136       -8.792648       -4.351837  -4.734052
# 2018   0.776363  -3.844027        0.342967        3.573529   2.212155
# 2019  11.015972  14.139810       10.887075        9.083269  10.319692
# 2020   6.921700  19.251529       17.340087       14.602811  13.861245
#
#         Vitória   Curitiba  Florianópolis  Porto Alegre      Belém    Aracaju  \
# 2012  10.123167   7.702659       6.694463      6.979525   9.837464   8.159741
# 2013  12.743218  10.521334       9.857200     11.343951  15.131860  16.585171
# 2014   5.794728   8.152919      14.584441      6.813049   3.039503   0.453651
# 2015   9.445420  13.489801      10.111121     12.063902   7.929544  19.504090
# 2016  16.553337  15.246574      18.046480     18.639937  24.980283  29.251337
# 2017  -5.173621  -5.518962      -3.694114     -1.548384  -6.820223  -2.587229
# 2018   0.538944   2.688709       0.841329     -1.054474  -3.928004  -1.942407
# 2019  13.112547   8.648662       8.593624      7.877194   7.960307   4.597037
# 2020  14.420809  16.377587      14.931849     13.126366  13.136945  13.113215
#
#       Fortaleza  João Pessoa      Natal     Recife   Salvador
# 2012  10.588235    12.592593   6.469543  12.414682   5.138321
# 2013  16.940426    18.915578  17.643031  18.049423  20.509770
# 2014   3.194935    -0.427001  -0.472865   3.478042   1.685969
# 2015  11.488416    12.279524   7.663913   7.556482  16.748198
# 2016  24.806275    22.822982  18.249092  16.193769  15.359519
# 2017  -0.347187    -3.645016  -0.574135  -2.992630  -5.595298
# 2018  -1.332553    -3.297413  -1.515808  -1.923794  -3.718280
# 2019   8.572386     9.771032   9.979478  11.462231  11.616131
# 2020  13.963205    13.654629  14.287999  16.677594  17.280678

# %%
# Acrescentando um índice para ser o índice inicial
cesta_evolucao_perc.loc[2011] = 0

# Ordenando os dados pelo índice
cesta_evolucao_perc = cesta_evolucao_perc.sort_index(ascending=True)

cesta_evolucao_perc
# Out:
#        Brasília    Goiânia  Belo Horizonte  Rio de Janeiro  São Paulo  \
# 2011   0.000000   0.000000        0.000000        0.000000   0.000000
# 2012   7.613310   5.252252       10.571154        8.488157   9.036750
# 2013  11.357830  10.731649       11.257009       12.378711  12.153394
# 2014   5.766051   4.796807        2.344182        7.194175   5.014767
# 2015  14.473013  12.661866       10.064172       11.378937  12.974775
# 2016  23.561377  20.891853       19.029614       19.922824  17.151290
# 2017  -8.784393  -3.447136       -8.792648       -4.351837  -4.734052
# 2018   0.776363  -3.844027        0.342967        3.573529   2.212155
# 2019  11.015972  14.139810       10.887075        9.083269  10.319692
# 2020   6.921700  19.251529       17.340087       14.602811  13.861245
#
#         Vitória   Curitiba  Florianópolis  Porto Alegre      Belém    Aracaju  \
# 2011   0.000000   0.000000       0.000000      0.000000   0.000000   0.000000
# 2012  10.123167   7.702659       6.694463      6.979525   9.837464   8.159741
# 2013  12.743218  10.521334       9.857200     11.343951  15.131860  16.585171
# 2014   5.794728   8.152919      14.584441      6.813049   3.039503   0.453651
# 2015   9.445420  13.489801      10.111121     12.063902   7.929544  19.504090
# 2016  16.553337  15.246574      18.046480     18.639937  24.980283  29.251337
# 2017  -5.173621  -5.518962      -3.694114     -1.548384  -6.820223  -2.587229
# 2018   0.538944   2.688709       0.841329     -1.054474  -3.928004  -1.942407
# 2019  13.112547   8.648662       8.593624      7.877194   7.960307   4.597037
# 2020  14.420809  16.377587      14.931849     13.126366  13.136945  13.113215
#
#       Fortaleza  João Pessoa      Natal     Recife   Salvador
# 2011   0.000000     0.000000   0.000000   0.000000   0.000000
# 2012  10.588235    12.592593   6.469543  12.414682   5.138321
# 2013  16.940426    18.915578  17.643031  18.049423  20.509770
# 2014   3.194935    -0.427001  -0.472865   3.478042   1.685969
# 2015  11.488416    12.279524   7.663913   7.556482  16.748198
# 2016  24.806275    22.822982  18.249092  16.193769  15.359519
# 2017  -0.347187    -3.645016  -0.574135  -2.992630  -5.595298
# 2018  -1.332553    -3.297413  -1.515808  -1.923794  -3.718280
# 2019   8.572386     9.771032   9.979478  11.462231  11.616131
# 2020  13.963205    13.654629  14.287999  16.677594  17.280678

# %%
cesta_evolucao_perc.describe()
# Out:
#         Brasília    Goiânia  Belo Horizonte  Rio de Janeiro  São Paulo  \
# count  10.000000  10.000000       10.000000       10.000000  10.000000
# mean    7.270122   8.043460        7.304361        8.227058   7.799002
# std     8.839933   8.899429        8.631189        7.102803   6.949964
# min    -8.784393  -3.844027       -8.792648       -4.351837  -4.734052
# 25%     2.023785   1.199202        0.843270        4.478691   2.912808
# 50%     7.267505   7.991950       10.317663        8.785713   9.678221
# 75%    11.272365  13.770324       11.164525       12.128768  12.769430
# max    23.561377  20.891853       19.029614       19.922824  17.151290
#
#          Vitória   Curitiba  Florianópolis  Porto Alegre      Belém  \
# count  10.000000  10.000000      10.000000     10.000000  10.000000
# mean    7.755855   7.730928       7.996639      7.424107   7.126768
# std     7.204154   6.944003       7.104762      6.695679   9.497730
# min    -5.173621  -5.518962      -3.694114     -1.548384  -6.820223
# 25%     1.852890   3.942197       2.304613      1.703262   0.759876
# 50%     9.784294   8.400790       9.225412      7.428359   7.944926
# 75%    13.020215  12.747684      13.466111     11.883914  12.312075
# max    16.553337  16.377587      18.046480     18.639937  24.980283
#
#          Aracaju  Fortaleza  João Pessoa      Natal     Recife   Salvador
# count  10.000000  10.000000    10.000000  10.000000  10.000000  10.000000
# mean    8.713461   8.787414     8.266691   7.173025   8.091580   7.902501
# std    10.657377   8.529674     9.492274   7.724143   8.019327   9.548162
# min    -2.587229  -1.332553    -3.645016  -1.515808  -2.992630  -5.595298
# 25%     0.113413   0.798734    -0.320251  -0.354649   0.869510   0.421492
# 50%     6.378389   9.580311    11.025278   7.066728   9.509357   8.377226
# 75%    15.717182  13.344508    13.389120  13.210869  15.248998  16.401028
# max    29.251337  24.806275    22.822982  18.249092  18.049423  20.509770

# %%
plt.style.use('fivethirtyeight')

plt.figure(figsize=(28,16))

plt.title('Variação Percentual do Valor da Cesta Básica nas capitais entre 2011 e 2020')

plt.subplot(4,4,1)
plt.bar(cesta_evolucao_perc.index,cesta_evolucao_perc['Brasília'].values, color='chocolate')
plt.title('Brasília',loc='center')

plt.subplot(4,4,2)
plt.bar(cesta_evolucao_perc.index,cesta_evolucao_perc['Goiânia'].values, color='chocolate')
plt.title('Goiânia',loc='center')

plt.subplot(4,4,3)
plt.bar(cesta_evolucao_perc.index,cesta_evolucao_perc['Belo Horizonte'].values, color='chocolate')
plt.title('Belo Horizonte',loc='center')

plt.subplot(4,4,4)
plt.bar(cesta_evolucao_perc.index,cesta_evolucao_perc['Rio de Janeiro'].values, color='chocolate')
plt.title('Rio de Janeiro',loc='center')

plt.subplot(4,4,5)
plt.bar(cesta_evolucao_perc.index,cesta_evolucao_perc['São Paulo'].values, color='chocolate')
plt.title('São Paulo',loc='center')

plt.subplot(4,4,6)
plt.bar(cesta_evolucao_perc.index,cesta_evolucao_perc['Vitória'].values, color='chocolate')
plt.title('Vitória',loc='center')

plt.subplot(4,4,7)
plt.bar(cesta_evolucao_perc.index,cesta_evolucao_perc['Curitiba'].values, color='chocolate')
plt.title('Curitiba',loc='center')

plt.subplot(4,4,8)
plt.bar(cesta_evolucao_perc.index,cesta_evolucao_perc['Florianópolis'].values, color='chocolate')
plt.title('Florianópolis',loc='center')

plt.subplot(4,4,9)
plt.bar(cesta_evolucao_perc.index,cesta_evolucao_perc['Porto Alegre'].values, color='chocolate')
plt.title('Porto Alegre',loc='center')

plt.subplot(4,4,10)
plt.bar(cesta_evolucao_perc.index,cesta_evolucao_perc['Belém'].values, color='chocolate')
plt.title('Belém',loc='center')

plt.subplot(4,4,11)
plt.bar(cesta_evolucao_perc.index,cesta_evolucao_perc['Aracaju'].values, color='chocolate')
plt.title('Aracaju',loc='center')

plt.subplot(4,4,12)
plt.bar(cesta_evolucao_perc.index,cesta_evolucao_perc['Fortaleza'].values, color='chocolate')
plt.title('Fortaleza',loc='center')

plt.subplot(4,4,13)
plt.bar(cesta_evolucao_perc.index,cesta_evolucao_perc['João Pessoa'].values, color='chocolate')
plt.title('João Pessoa',loc='center')

plt.subplot(4,4,14)
plt.bar(cesta_evolucao_perc.index,cesta_evolucao_perc['Natal'].values, color='chocolate')
plt.title('Natal',loc='center')

plt.subplot(4,4,15)
plt.bar(cesta_evolucao_perc.index,cesta_evolucao_perc['Recife'].values, color='chocolate')
plt.title('Recife',loc='center')

plt.subplot(4,4,16)
plt.bar(cesta_evolucao_perc.index,cesta_evolucao_perc['Salvador'].values, color='chocolate')
plt.title('Salvador',loc='center')


plt.show()

# %%
# Diferença percentual entre o valor da cesta básica do ano de 2020 em comparação com o valor de 2011

for i in cesta.columns:
    n =  ((cesta[i][2020] / cesta[i][2011]) -1) * 100
    print(f'{i:<15} - {round(n,2):>10}')
# Out:
# Brasília        -      95.61
# Goiânia         -     110.22
# Belo Horizonte  -      96.42
# Rio de Janeiro  -     116.18
# São Paulo       -     107.89
# Vitória         -     106.74
# Curitiba        -     106.56
# Florianópolis   -      111.6
# Porto Alegre    -     101.09
# Belém           -      92.18
# Aracaju         -     121.12
# Fortaleza       -     125.92
# João Pessoa     -     113.73
# Natal           -      95.33
# Recife          -     112.34
# Salvador        -     106.46

# %%
cesta.head(10).T
# Out:
#                   2011    2012    2013    2014    2015    2016    2017  \
# Brasília        247.33  266.16  296.39  313.48  358.85  443.40  404.45
# Goiânia         236.47  248.89  275.60  288.82  325.39  393.37  379.81
# Belo Horizonte  250.02  276.45  307.57  314.78  346.46  412.39  376.13
# Rio de Janeiro  254.59  276.20  310.39  332.72  370.58  444.41  425.07
# São Paulo       268.57  292.84  328.43  344.90  389.65  456.48  434.87
# Vitória         255.75  281.64  317.53  335.93  367.66  428.52  406.35
# Curitiba        245.24  264.13  291.92  315.72  358.31  412.94  390.15
# Florianópolis   256.63  273.81  300.80  344.67  379.52  448.01  431.46
# Porto Alegre    267.64  286.32  318.80  340.52  381.60  452.73  445.72
# Belém           234.41  257.47  296.43  305.44  329.66  412.01  383.91
# Aracaju         185.30  200.42  233.66  234.72  280.50  362.55  353.17
# Fortaleza       212.50  235.00  274.81  283.59  316.17  394.60  393.23
# João Pessoa     201.15  226.48  269.32  268.17  301.10  369.82  356.34
# Natal           219.49  233.69  274.92  273.62  294.59  348.35  346.35
# Recife          209.51  235.52  278.03  287.70  309.44  359.55  348.79
# Salvador        207.85  218.53  263.35  267.79  312.64  360.66  340.48
#
#                   2018    2019    2020
# Brasília        407.59  452.49  483.81
# Goiânia         365.21  416.85  497.10
# Belo Horizonte  377.42  418.51  491.08
# Rio de Janeiro  440.26  480.25  550.38
# São Paulo       444.49  490.36  558.33
# Vitória         408.54  462.11  528.75
# Curitiba        400.64  435.29  506.58
# Florianópolis   435.09  472.48  543.03
# Porto Alegre    441.02  475.76  538.21
# Belém           368.83  398.19  450.50
# Aracaju         346.31  362.23  409.73
# Fortaleza       387.99  421.25  480.07
# João Pessoa     344.59  378.26  429.91
# Natal           341.10  375.14  428.74
# Recife          342.08  381.29  444.88
# Salvador        327.82  365.90  429.13

# %%
cesta.index
# Out:
# Int64Index([2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020], dtype='int64')

# %%
cesta['Vitória'][[2013,2017]]
# Out:
# 2013    317.53
# 2017    406.35
# Name: Vitória, dtype: float64

# %%
plt.style.use('fivethirtyeight')
cesta[['Vitória','Brasília']].plot(kind='line', figsize=(12,6))
plt.xticks(cesta.index)
plt.show()

# %%
plt.figure(figsize=(28,6))

plt.subplot(1,4,1)
plt.plot(cesta[['Belo Horizonte','Rio de Janeiro','São Paulo','Vitória']], label=['Belo Horizonte','Rio de Janeiro','São Paulo','Vitória'])
#plt.yticks([150, 250, 350, 450, 550],labels=[150, 250, 350, 450, 550])
plt.title('Região Sudeste')
plt.legend()

plt.subplot(1,4,2)
plt.plot(cesta[['Curitiba','Florianópolis','Porto Alegre']], label=['Curitiba','Florianópolis','Porto Alegre'])
plt.title('Região Sul')
plt.legend()

plt.subplot(1,4,3)
plt.plot(cesta[['Brasília','Goiânia']], label=['Brasília','Goiânia'])
plt.title('Região Centroeste')
plt.legend()

plt.subplot(1,4,4)
plt.plot(cesta[['Aracaju','Fortaleza','João Pessoa','Natal','Recife','Salvador']], label=['Aracaju','Fortaleza','João Pessoa','Natal','Recife','Salvador'])
plt.title('Região Nordeste')
plt.legend()

plt.show()

# %%
plt.style.use('fivethirtyeight')

ax = cesta[['São Paulo','Vitória', 'Brasília', 'Goiânia', 'Salvador', 'Aracaju']].plot(rot=0, kind='bar', figsize=(30,8), width=0.7)

plt.show()

# %%
plt.style.use('fivethirtyeight')

media = (cesta['São Paulo'] + cesta['Vitória'] + cesta['Brasília'] + cesta['Goiânia'] + cesta['Salvador'] + cesta['Aracaju'])/6

fig = plt.subplots(figsize=(30,8))

plt.bar(cesta.index-0.30, cesta['São Paulo'],width=0.12, alpha=0.8)
plt.bar(cesta.index-0.18, cesta['Vitória'],width=0.12,color='orange' ,alpha=0.8)
plt.bar(cesta.index-0.06, cesta['Brasília'],width=0.12,alpha=0.8)
plt.bar(cesta.index+0.06, cesta['Goiânia'],width=0.12,alpha=0.8)
plt.bar(cesta.index+0.18, cesta['Salvador'],width=0.12,alpha=0.8)
plt.bar(cesta.index+0.30, cesta['Aracaju'],width=0.12,alpha=0.8)

plt.xticks(cesta.index, labels=cesta.index)

plt.plot(media.index, media, color='r')

plt.legend(['Média','São Paulo', 'Vitória', 'Brasília', 'Goiânia', 'Salvador','Aracaju'])

plt.show()

# %%
cesta.loc[2015].sort_values(ascending=[False])
# Out:
# São Paulo         389.65
# Porto Alegre      381.60
# Florianópolis     379.52
# Rio de Janeiro    370.58
# Vitória           367.66
# Brasília          358.85
# Curitiba          358.31
# Belo Horizonte    346.46
# Belém             329.66
# Goiânia           325.39
# Fortaleza         316.17
# Salvador          312.64
# Recife            309.44
# João Pessoa       301.10
# Natal             294.59
# Aracaju           280.50
# Name: 2015, dtype: float64

# %%
cesta.describe()
# Out:
#          Brasília     Goiânia  Belo Horizonte  Rio de Janeiro   São Paulo  \
# count   10.000000   10.000000       10.000000        10.00000   10.000000
# mean   367.395000  342.751000      357.081000       388.48500  400.892000
# std     83.163003   82.717113       72.939712        95.36041   92.275636
# min    247.330000  236.470000      250.020000       254.59000  268.570000
# 25%    300.662500  278.905000      309.372500       315.97250  332.547500
# 50%    381.650000  345.300000      361.295000       397.82500  412.260000
# 75%    434.447500  389.980000      403.647500       443.37250  453.482500
# max    483.810000  497.100000      491.080000       550.38000  558.330000
#
#           Vitória   Curitiba  Florianópolis  Porto Alegre       Belém  \
# count   10.000000   10.00000      10.000000     10.000000   10.000000
# mean   379.278000  362.09200     388.550000    394.832000  343.685000
# std     84.219383   82.61905      93.527333     89.467619   70.368344
# min    255.750000  245.24000     256.630000    267.640000  234.410000
# 25%    322.130000  297.87000     311.767500    324.230000  298.682500
# 50%    387.005000  374.23000     405.490000    411.310000  349.245000
# 75%    423.525000  409.86500     444.780000    450.977500  394.620000
# max    528.750000  506.58000     543.030000    538.210000  450.500000
#
#           Aracaju   Fortaleza  João Pessoa       Natal      Recife    Salvador
# count   10.000000   10.000000    10.000000   10.000000   10.000000   10.000000
# mean   296.859000  339.921000   314.514000  313.599000  319.679000  309.415000
# std     79.452113   87.951806    73.078424   65.641272   70.310609   69.835221
# min    185.300000  212.500000   201.150000  219.490000  209.510000  207.850000
# 25%    233.925000  277.005000   268.457500  273.945000  280.447500  264.460000
# 50%    313.405000  352.080000   322.845000  317.845000  325.760000  320.230000
# 75%    359.965000  394.257500   366.450000  347.850000  356.860000  355.615000
# max    409.730000  480.070000   429.910000  428.740000  444.880000  429.130000

# %%
cesta1 = cesta.loc[[2012]]
cesta1
# Out:
#       Brasília  Goiânia  Belo Horizonte  Rio de Janeiro  São Paulo  Vitória  \
# 2012    266.16   248.89          276.45           276.2     292.84   281.64
#
#       Curitiba  Florianópolis  Porto Alegre   Belém  Aracaju  Fortaleza  \
# 2012    264.13         273.81        286.32  257.47   200.42      235.0
#
#       João Pessoa   Natal  Recife  Salvador
# 2012       226.48  233.69  235.52    218.53

# %%
# Retirando as colunas que contem elementos com valor 0

cesta1 = cesta.loc[[2012]]
for i in cesta.columns:
    if float(cesta1[i]) == 0:
        cesta1 = cesta1.drop(columns=[i])

cesta1
# Out:
#       Brasília  Goiânia  Belo Horizonte  Rio de Janeiro  São Paulo  Vitória  \
# 2012    266.16   248.89          276.45           276.2     292.84   281.64
#
#       Curitiba  Florianópolis  Porto Alegre   Belém  Aracaju  Fortaleza  \
# 2012    264.13         273.81        286.32  257.47   200.42      235.0
#
#       João Pessoa   Natal  Recife  Salvador
# 2012       226.48  233.69  235.52    218.53

# %%
# Criando duas funções para descobrir os valores máximos e mínimos da cesta básica em cada ano observado

city_high = []
value_high = []
city_low = []
value_low = []
difference = []

def maximum(year):
    maior = cesta.loc[year].idxmax()
    return maior

def minimum(year):
    cesta1 = cesta.loc[[year]]
    for i in cesta.columns:
        if float(cesta1[i]) == 0:
            cesta1 = cesta1.drop(columns=[i])
    menor = cesta1.loc[year].idxmin()
    return menor

print(f'{"Data"}  -  {"Cidade mais cara":.<10}{"Valor":>11}     {"Cidade mais barata":.<12}{"Valor":>9}')

for i in cesta.index:
    city_high.append(maximum(i))
    value_high.append(cesta[maximum(i)][i])
    city_low.append(minimum(i))
    value_low.append(cesta[minimum(i)][i])
    difference.append(cesta[maximum(i)][i] - cesta[minimum(i)][i])

    print(f'{i}  -  {maximum(i):.<18}{cesta[maximum(i)][i]:.>10.2f}    {minimum(i):.<18}{cesta[minimum(i)][i]:.>10.2f}' )
# Out:
# Data  -  Cidade mais cara      Valor     Cidade mais barata    Valor
# 2011  -  São Paulo.............268.57    Aracaju...............185.30
# 2012  -  São Paulo.............292.84    Aracaju...............200.42
# 2013  -  São Paulo.............328.43    Aracaju...............233.66
# 2014  -  São Paulo.............344.90    Aracaju...............234.72
# 2015  -  São Paulo.............389.65    Aracaju...............280.50
# 2016  -  São Paulo.............456.48    Natal.................348.35
# 2017  -  Porto Alegre..........445.72    Salvador..............340.48
# 2018  -  São Paulo.............444.49    Salvador..............327.82
# 2019  -  São Paulo.............490.36    Aracaju...............362.23
# 2020  -  São Paulo.............558.33    Aracaju...............409.73

# %%
difference
# Out:
# [83.26999999999998,
#  92.41999999999999,
#  94.77000000000001,
#  110.17999999999998,
#  109.14999999999998,
#  108.13,
#  105.24000000000001,
#  116.67000000000002,
#  128.13,
#  148.60000000000002]

# %%
# Gráfico com valores anuais da cesta básica da cidade mais cara e mais barata entre 2011 e 2020

plt.style.use('fivethirtyeight')

fig, ax = plt.subplots(figsize=(18,8))

p1 = ax.bar(cesta.index,value_high, label='Cidades mais caras')
p2 = ax.bar(cesta.index,value_low, label='Cidades mais baratas')


ax.bar_label(p1, label_type='edge', fontsize=14)
ax.bar_label(p2, label_type='center', fontsize=14)
ax.legend(fontsize=16)

ax.set_xticks(cesta.index, labels=[2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020])

#plt.text(value_high[0], ha = 'center', bbox = dict(facecolor ='cyan', alpha =0.8))

#plt.xticks(np.arange(min(cesta.index), max(cesta.index)+1, 1.0))

plt.show()

# %%
# Diferença percentual entre o valor da cesta básica na cidade mais cara e mais barata entre 2011 e 2020

percentual_maior_menor = []

print('Data    Cidade mais cara      Cidade Mais Barata      Diferença percentual')

for i in range(len(value_high)):
    perc = round((((value_high[i] / value_low[i]) -1) * 100),2)
    percentual_maior_menor.append(perc)
    print(f'{cesta.index[i]:<10}{city_high[i]:<25}{city_low[i]:<22}{perc:>8}%')

percentual_maior_menor
# Out:
# Data    Cidade mais cara      Cidade Mais Barata      Diferença percentual
# 2011      São Paulo                Aracaju                  44.94%
# 2012      São Paulo                Aracaju                  46.11%
# 2013      São Paulo                Aracaju                  40.56%
# 2014      São Paulo                Aracaju                  46.94%
# 2015      São Paulo                Aracaju                  38.91%
# 2016      São Paulo                Natal                    31.04%
# 2017      Porto Alegre             Salvador                 30.91%
# 2018      São Paulo                Salvador                 35.59%
# 2019      São Paulo                Aracaju                  35.37%
# 2020      São Paulo                Aracaju                  36.27%
# [44.94, 46.11, 40.56, 46.94, 38.91, 31.04, 30.91, 35.59, 35.37, 36.27]

# %%
# Gráfico que mostra a diferença percentual entre o valor da cesta básica na cidade mais cara e mais barata entre 2011 e 2020

plt.style.use('fivethirtyeight')

fig, ax = plt.subplots(figsize=(18,10))

index = [0, 10, 20, 30, 40, 50]

p = ax.barh(cesta.index, percentual_maior_menor, label='Cidades mais caras') #color=['#FFE4B5', '#FFDEAD', '#FFDAB9', '#FFE4C4', '#FFEBCD', '#FFEFD5','#FAEBD7', '#FAF0E6', '#FDF5E6', '#FFFAF0'])

ax.bar_label(p, label_type='edge', fontsize=18, bbox = dict(facecolor = 'cyan', alpha =0.8))

ax.set_yticks(cesta.index, labels=[2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020])
ax.set_xticks(index, labels=[0, 10, 20, 30, 40, 50])

ax.set_title('Diferença percentual entre a cesta básica mais cara e mais barata no período', fontsize=25, weight='semibold', pad=20)

ax.set_xlabel('Valor Percentual', fontsize=20)
ax.set_ylabel('Ano', fontsize=20)

plt.show()

# %%
# Descobrindo a média anual do valor da cesta básica entre todas as capitais brasileiras entre 2011 e 2020

dict_media_anual = {}

for p in cesta.index:
    count = 0
    for i in cesta.loc[p]:
        if i > 0:
            count += 1

    media_anual = round(((sum(cesta.loc[p])) / count), 2)
    dict_media_anual[p] = media_anual

dict_media_anual
# Out:
# {2011: 234.53,
#  2012: 254.6,
#  2013: 289.87,
#  2014: 303.29,
#  2015: 338.88,
#  2016: 406.24,
#  2017: 388.52,
#  2018: 386.19,
#  2019: 424.15,
#  2020: 485.64}

# %%
# Criando um dataframe com a média anual do valor da cesta básica entre as capitais brasileiras entre 2011 e 2020

cesta_basica = pd.DataFrame(dict_media_anual.values(), index=[2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020], columns=['Mean'])

cesta_basica
# Out:
#         Mean
# 2011  234.53
# 2012  254.60
# 2013  289.87
# 2014  303.29
# 2015  338.88
# 2016  406.24
# 2017  388.52
# 2018  386.19
# 2019  424.15
# 2020  485.64

# %%
# Gráfico que mostra a média anual do valor da cesta básica entre as capitais brasileiras entre 2011 e 2020

plt.style.use('fivethirtyeight')

fig, ax = plt.subplots(figsize=(14,8))

p1 = ax.bar(cesta_basica.index, cesta_basica['Mean'], width=0.5)
p2 = ax.plot(cesta_basica.index, cesta_basica['Mean'], color='r')

ax.bar_label(p1, fontsize=12, padding=10, color='black')

ax.set_xticks(cesta_basica.index, labels=cesta_basica.index)

plt.show()

# %%
plt.style.use('fivethirtyeight')

fig, ax = plt.subplots(figsize=(14,8))

#plt.grid(axis='y', zorder=1)

ax = plt.bar(cesta_basica.index, cesta_basica['Mean'], width=0.5, zorder=2)
ax2 = plt.plot(cesta_basica.index, cesta_basica['Mean'], color='red', zorder=2)

plt.bar_label(p1, fontsize=12, padding=10, color='black')

plt.xticks(np.arange(min(cesta_basica.index), max(cesta_basica.index)+1, 1.0))

plt.show()

# %%
# Obtendo a media por ano de maneira fácil com numpy (contando os zeros)
round(cesta.mean(axis=1),2)
# Out:
# 2011    234.53
# 2012    254.60
# 2013    289.87
# 2014    303.29
# 2015    338.88
# 2016    406.24
# 2017    388.52
# 2018    386.19
# 2019    424.15
# 2020    485.64
# dtype: float64
