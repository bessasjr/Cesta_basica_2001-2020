# %% [markdown]
# Análise profunda da evolução do valor da cesta básica nas capitais brasileiras num período de 20 anos (2001 a 2020)
#
# Dados da Cesta Básica - Fonte: Dieese (https://www.dieese.org.br/cesta/)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Lendo o arquivo que contem valores da cesta básica nas capitais brasileiras de todos os meses, entre 2001 e 2020

cest = pd.read_excel('Cesta_basica_br.xls')

#cest.head(10).T
cest
# Out:
#                                             Unnamed: 0  Brasília  \
# 0                                              01-2001    114.06
# 1                                              02-2001    113.44
# 2                                              03-2001    114.00
# 3                                              04-2001    117.56
# 4                                              05-2001    118.64
# ..                                                 ...       ...
# 239                                            11-2020    572.64
# 240                                            12-2020    591.82
# 241                                      Fonte: DIEESE       NaN
# 242  (1) Série recalculada, conforme mudança metodo...       NaN
# 243  Tomada especial de preços a partir de abril de...       NaN
#
#      Campo Grande  Cuiabá  Goiânia  Belo Horizonte  Rio de Janeiro  São Paulo  \
# 0             NaN     NaN    99.13          117.55          116.61     123.36
# 1             NaN     NaN    98.03          118.45          114.61     123.44
# 2             NaN     NaN    98.42          118.83          117.60     124.76
# 3             NaN     NaN   102.99          127.38          118.58     129.49
# 4             NaN     NaN   102.44          123.72          122.65     129.78
# ..            ...     ...      ...             ...             ...        ...
# 239        589.08     NaN   557.46          552.37          629.63     629.18
# 240        576.48     NaN   563.80          568.53          621.09     631.46
# 241           NaN     NaN      NaN             NaN             NaN        NaN
# 242           NaN     NaN      NaN             NaN             NaN        NaN
# 243           NaN     NaN      NaN             NaN             NaN        NaN
#
#      Vitória  Curitiba  ...  Rio Branco  Aracaju  Fortaleza  João Pessoa  \
# 0      94.81    115.10  ...         NaN    98.46      92.33        92.92
# 1      97.25    112.21  ...         NaN    99.25      91.82        91.05
# 2     104.88    116.19  ...         NaN    99.46      93.24        92.16
# 3     113.20    123.76  ...         NaN    99.74      96.50        95.70
# 4     110.94    123.06  ...         NaN   104.72     102.47        96.55
# ..       ...       ...  ...         ...      ...        ...          ...
# 239   606.59    547.29  ...         NaN   451.32     539.33       454.85
# 240   600.28    540.36  ...         NaN   453.16     534.96       475.19
# 241      NaN       NaN  ...         NaN      NaN        NaN          NaN
# 242      NaN       NaN  ...         NaN      NaN        NaN          NaN
# 243      NaN       NaN  ...         NaN      NaN        NaN          NaN
#
#      Maceió   Natal  Recife  Salvador  São Luís  Teresina
# 0       NaN   95.81   97.18     90.72       NaN       NaN
# 1       NaN   94.15   88.81     89.08       NaN       NaN
# 2       NaN   95.46   87.24     89.11       NaN       NaN
# 3       NaN   95.72   89.95     89.92       NaN       NaN
# 4       NaN   99.24   96.01     93.72       NaN       NaN
# ..      ...     ...     ...       ...       ...       ...
# 239     NaN  455.43  462.98    488.10       NaN       NaN
# 240     NaN  458.79  469.39    479.08       NaN       NaN
# 241     NaN     NaN     NaN       NaN       NaN       NaN
# 242     NaN     NaN     NaN       NaN       NaN       NaN
# 243     NaN     NaN     NaN       NaN       NaN       NaN
#
# [244 rows x 28 columns]

# %%
cest.shape
# Out:
# (244, 28)

# %%
cest.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 28 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      244 non-null    object
#  1   Brasília        240 non-null    float64
#  2   Campo Grande    100 non-null    float64
#  3   Cuiabá          33 non-null     float64
#  4   Goiânia         241 non-null    float64
#  5   Belo Horizonte  241 non-null    float64
#  6   Rio de Janeiro  241 non-null    float64
#  7   São Paulo       241 non-null    float64
#  8   Vitória         241 non-null    float64
#  9   Curitiba        241 non-null    float64
#  10  Florianópolis   241 non-null    float64
#  11  Porto Alegre    241 non-null    float64
#  12  Belém           241 non-null    float64
#  13  Boa Vista       21 non-null     float64
#  14  Macapá          21 non-null     float64
#  15  Manaus          121 non-null    float64
#  16  Palmas          20 non-null     float64
#  17  Porto Velho     21 non-null     float64
#  18  Rio Branco      20 non-null     float64
#  19  Aracaju         241 non-null    float64
#  20  Fortaleza       241 non-null    float64
#  21  João Pessoa     241 non-null    float64
#  22  Maceió          25 non-null     float64
#  23  Natal           241 non-null    float64
#  24  Recife          241 non-null    float64
#  25  Salvador        241 non-null    float64
#  26  São Luís        41 non-null     float64
#  27  Teresina        20 non-null     float64
# dtypes: float64(27), object(1)
# memory usage: 53.5+ KB

# %%
# Verificando se existe campos com valores nulos e quantos são em cada coluna
cest.isnull().sum()
# Out:
# Data                0
# Brasília            1
# Campo Grande      141
# Cuiabá            208
# Goiânia             0
# Belo Horizonte      0
# Rio de Janeiro      0
# São Paulo           0
# Vitória             0
# Curitiba            0
# Florianópolis       0
# Porto Alegre        0
# Belém               0
# Boa Vista         220
# Macapá            220
# Manaus            120
# Palmas            221
# Porto Velho       220
# Rio Branco        221
# Aracaju             0
# Fortaleza           0
# João Pessoa         0
# Maceió            216
# Natal               0
# Recife              0
# Salvador            0
# São Luís          200
# Teresina          221
# dtype: int64

# %%
# Verificando se existe valores duplicados e quantos são em cada coluna
cest.duplicated().sum()
# Out:
# 0

# %%
cest.rename(columns={'Unnamed: 0': 'Data'}, inplace=True)
cest
# Out:
#                                                   Data  Brasília  \
# 0                                              01-2001    114.06
# 1                                              02-2001    113.44
# 2                                              03-2001    114.00
# 3                                              04-2001    117.56
# 4                                              05-2001    118.64
# ..                                                 ...       ...
# 239                                            11-2020    572.64
# 240                                            12-2020    591.82
# 241                                      Fonte: DIEESE       NaN
# 242  (1) Série recalculada, conforme mudança metodo...       NaN
# 243  Tomada especial de preços a partir de abril de...       NaN
#
#      Campo Grande  Cuiabá  Goiânia  Belo Horizonte  Rio de Janeiro  São Paulo  \
# 0             NaN     NaN    99.13          117.55          116.61     123.36
# 1             NaN     NaN    98.03          118.45          114.61     123.44
# 2             NaN     NaN    98.42          118.83          117.60     124.76
# 3             NaN     NaN   102.99          127.38          118.58     129.49
# 4             NaN     NaN   102.44          123.72          122.65     129.78
# ..            ...     ...      ...             ...             ...        ...
# 239        589.08     NaN   557.46          552.37          629.63     629.18
# 240        576.48     NaN   563.80          568.53          621.09     631.46
# 241           NaN     NaN      NaN             NaN             NaN        NaN
# 242           NaN     NaN      NaN             NaN             NaN        NaN
# 243           NaN     NaN      NaN             NaN             NaN        NaN
#
#      Vitória  Curitiba  ...  Rio Branco  Aracaju  Fortaleza  João Pessoa  \
# 0      94.81    115.10  ...         NaN    98.46      92.33        92.92
# 1      97.25    112.21  ...         NaN    99.25      91.82        91.05
# 2     104.88    116.19  ...         NaN    99.46      93.24        92.16
# 3     113.20    123.76  ...         NaN    99.74      96.50        95.70
# 4     110.94    123.06  ...         NaN   104.72     102.47        96.55
# ..       ...       ...  ...         ...      ...        ...          ...
# 239   606.59    547.29  ...         NaN   451.32     539.33       454.85
# 240   600.28    540.36  ...         NaN   453.16     534.96       475.19
# 241      NaN       NaN  ...         NaN      NaN        NaN          NaN
# 242      NaN       NaN  ...         NaN      NaN        NaN          NaN
# 243      NaN       NaN  ...         NaN      NaN        NaN          NaN
#
#      Maceió   Natal  Recife  Salvador  São Luís  Teresina
# 0       NaN   95.81   97.18     90.72       NaN       NaN
# 1       NaN   94.15   88.81     89.08       NaN       NaN
# 2       NaN   95.46   87.24     89.11       NaN       NaN
# 3       NaN   95.72   89.95     89.92       NaN       NaN
# 4       NaN   99.24   96.01     93.72       NaN       NaN
# ..      ...     ...     ...       ...       ...       ...
# 239     NaN  455.43  462.98    488.10       NaN       NaN
# 240     NaN  458.79  469.39    479.08       NaN       NaN
# 241     NaN     NaN     NaN       NaN       NaN       NaN
# 242     NaN     NaN     NaN       NaN       NaN       NaN
# 243     NaN     NaN     NaN       NaN       NaN       NaN
#
# [244 rows x 28 columns]

# %%
# Deletando as 3 ultimas linhas (que não contém mais dados)

cest = cest.iloc[:241]
cest
# Out:
#         Data  Brasília  Campo Grande  Cuiabá  Goiânia  Belo Horizonte  \
# 0    01-2001    114.06           NaN     NaN    99.13          117.55
# 1    02-2001    113.44           NaN     NaN    98.03          118.45
# 2    03-2001    114.00           NaN     NaN    98.42          118.83
# 3    04-2001    117.56           NaN     NaN   102.99          127.38
# 4    05-2001    118.64           NaN     NaN   102.44          123.72
# ..       ...       ...           ...     ...      ...             ...
# 236  08-2020    443.28        484.46     NaN   483.15          478.07
# 237  09-2020    445.76        492.80     NaN   510.52          491.62
# 238  10-2020    490.48        520.12     NaN   537.61          516.82
# 239  11-2020    572.64        589.08     NaN   557.46          552.37
# 240  12-2020    591.82        576.48     NaN   563.80          568.53
#
#      Rio de Janeiro  São Paulo  Vitória  Curitiba  ...  Rio Branco  Aracaju  \
# 0            116.61     123.36    94.81    115.10  ...         NaN    98.46
# 1            114.61     123.44    97.25    112.21  ...         NaN    99.25
# 2            117.60     124.76   104.88    116.19  ...         NaN    99.46
# 3            118.58     129.49   113.20    123.76  ...         NaN    99.74
# 4            122.65     129.78   110.94    123.06  ...         NaN   104.72
# ..              ...        ...      ...       ...  ...         ...      ...
# 236          529.76     539.95   509.45    505.54  ...         NaN   398.47
# 237          563.75     563.35   539.36    524.25  ...         NaN   427.11
# 238          592.25     595.87   552.85    521.12  ...         NaN   442.26
# 239          629.63     629.18   606.59    547.29  ...         NaN   451.32
# 240          621.09     631.46   600.28    540.36  ...         NaN   453.16
#
#      Fortaleza  João Pessoa  Maceió   Natal  Recife  Salvador  São Luís  \
# 0        92.33        92.92     NaN   95.81   97.18     90.72       NaN
# 1        91.82        91.05     NaN   94.15   88.81     89.08       NaN
# 2        93.24        92.16     NaN   95.46   87.24     89.11       NaN
# 3        96.50        95.70     NaN   95.72   89.95     89.92       NaN
# 4       102.47        96.55     NaN   99.24   96.01     93.72       NaN
# ..         ...          ...     ...     ...     ...       ...       ...
# 236     462.13       414.50     NaN  419.47  439.19    418.72       NaN
# 237     485.75       432.04     NaN  422.31  464.31    459.33       NaN
# 238     510.54       449.97     NaN  436.76  469.05    454.50       NaN
# 239     539.33       454.85     NaN  455.43  462.98    488.10       NaN
# 240     534.96       475.19     NaN  458.79  469.39    479.08       NaN
#
#      Teresina
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# ..        ...
# 236       NaN
# 237       NaN
# 238       NaN
# 239       NaN
# 240       NaN
#
# [241 rows x 28 columns]

# %%
fig = plt.subplots(figsize=(6,4))

plt.hist(cest['São Paulo'], bins=16, color='darkviolet', edgecolor= 'black')

plt.show()

# %%
# Descobrindo a média anual do valor da cesta básica por capital e salvando em um dicionário


anos = ['2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020']

lista_mes = []
lista_ano = []

dic = {}

for s in cest.columns[1:]:
    for p in anos:
        for n in range(len(cest['Data'])):
            if cest['Data'][n][3:] == p:
                if cest[s][n] > 0:
                    lista_mes.append(cest[s][n])
                if len(lista_mes) > 0:
                    h = round((sum(lista_mes)/len(lista_mes)), 2)
                else:
                    h = np.nan
        lista_mes.clear()
        lista_ano.append(h)

    dic[s] = lista_ano[0:20]
    lista_ano.clear()

print(dic)
# Out:
# {'Brasília': [118.2, 129.28, 159.02, 165.4, 170.05, 168.38, 177.71, 220.94, 221.32, 226.25, 247.33, 266.16, 296.39, 313.48, 358.38, 443.4, 404.45, 407.59, 452.49, 483.81], 'Campo Grande': [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, 266.1, 295.3, 304.07, 346.18, 416.8, 379.21, 387.98, 429.37, 495.56], 'Cuiabá': [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, 428.0, 389.34, 397.92, nan, nan], 'Goiânia': [101.38, 115.54, 141.49, 147.42, 151.07, 147.81, 159.85, 199.39, 203.86, 215.53, 236.47, 248.89, 275.6, 288.82, 325.42, 393.36, 379.81, 365.21, 416.85, 497.1], 'Belo Horizonte': [118.88, 126.48, 152.76, 161.64, 163.46, 166.12, 180.43, 225.76, 217.33, 225.73, 250.02, 276.45, 307.57, 314.78, 346.99, 412.39, 376.13, 377.42, 418.51, 491.08], 'Rio de Janeiro': [120.54, 131.2, 157.13, 165.69, 169.81, 168.27, 183.99, 221.86, 220.09, 229.76, 254.59, 276.2, 310.39, 332.72, 370.27, 444.41, 425.07, 440.26, 480.25, 550.38], 'São Paulo': [126.36, 137.47, 167.28, 172.38, 178.75, 176.98, 193.37, 235.87, 229.82, 247.9, 268.57, 292.84, 328.43, 344.9, 389.15, 456.48, 434.87, 444.49, 490.36, 558.33], 'Vitória': [108.25, 121.31, 142.96, 151.83, 160.26, 157.63, 173.61, 214.13, 225.38, 231.48, 255.75, 281.64, 317.53, 335.93, 367.32, 428.52, 406.35, 408.54, 462.11, 528.75], 'Curitiba': [121.54, 131.84, 157.57, 161.77, 166.65, 163.64, 175.74, 218.35, 215.41, 226.93, 245.24, 264.13, 291.92, 315.72, 357.98, 412.94, 390.16, 400.64, 435.29, 506.58], 'Florianópolis': [115.72, 129.47, 153.11, 158.55, 163.93, 164.56, 177.93, 220.25, 219.67, 228.58, 256.63, 273.8, 300.8, 344.67, 378.69, 448.01, 431.46, 435.09, 472.48, 543.03], 'Porto Alegre': [126
# 2012    266.16        266.10     NaN   248.89          276.45          276.20
# 2013    296.39        295.30     NaN   275.60          307.57          310.39
# 2014    313.48        304.07     NaN   288.82          314.78          332.72
# 2015    358.38        346.18     NaN   325.42          346.99          370.27
# 2016    443.40        416.80  428.00   393.36          412.39          444.41
# 2017    404.45        379.21  389.34   379.81          376.13          425.07
# 2018    407.59        387.98  397.92   365.21          377.42          440.26
# 2019    452.49        429.37     NaN   416.85          418.51          480.25
# 2020    483.81        495.56     NaN   497.10          491.08          550.38
#
#       São Paulo  Vitória  Curitiba  Florianópolis  ...  Rio Branco  Aracaju  \
# 2001     126.36   108.25    121.54         115.72  ...         NaN   102.27
# 2002     137.47   121.31    131.84         129.47  ...         NaN   116.34
# 2003     167.28   142.96    157.57         153.11  ...         NaN   142.99
# 2004     172.38   151.83    161.77         158.55  ...         NaN   139.09
# 2005     178.75   160.26    166.65         163.93  ...         NaN   137.67
# 2006     176.98   157.63    163.64         164.56  ...         NaN   136.44
# 2007     193.37   173.61    175.74         177.93  ...         NaN   150.10
# 2008     235.87   214.13    218.35         220.25  ...         NaN   180.16
# 2009     229.82   225.38    215.41         219.67  ...         NaN   171.03
# 2010     247.90   231.48    226.93         228.58  ...         NaN   177.86
# 2011     268.57   255.75    245.24         256.63  ...         NaN   185.30
# 2012     292.84   281.64    264.13         273.80  ...         NaN   200.42
# 2013     328.43   317.53    291.92         300.80  ...         NaN   233.66
# 2014     344.90   335.93    315.72         344.67  ...         NaN   234.72
# 2015     389.15   367.32    357.98         378.69  ...         NaN   279.76
# 2016     456.48   428.52    412.94         448.01  ...      361.43   362.55
# 2017     434.87   406.35    390.16         431.46  ...      331.54   353.17
# 2018     444.49   408.54    400.64         435.09  ...         NaN   346.31
# 2019     490.36   462.11    435.29         472.48  ...         NaN   362.23
# 2020     558.33   528.75    506.58         543.03  ...         NaN   409.73
#
#       Fortaleza  João Pessoa  Maceió   Natal  Recife  Salvador  São Luís  \
# 2001      96.92        96.42     NaN   96.39   94.11     91.93       NaN
# 2002     109.99       108.09     NaN  111.98  108.88    107.29       NaN
# 2003     134.40       131.24     NaN  135.60  133.26    136.21       NaN
# 2004     135.56       137.04     NaN  138.72  133.86    135.08       NaN
# 2005     133.33       136.60     NaN  136.96  137.19    132.86       NaN
# 2006     130.27       135.99     NaN  135.63  135.14    136.02       NaN
# 2007     143.95       143.51     NaN  151.69  144.88    146.22       NaN
# 2008     184.09       180.81     NaN  193.87  178.68    180.80       NaN
# 2009     180.87       179.12     NaN  193.87  180.92    195.40       NaN
# 2010     187.03       189.60     NaN  204.84  198.93    204.13       NaN
# 2011     212.50       201.15     NaN  219.49  209.51    207.85       NaN
# 2012     235.00       226.48     NaN  233.69  235.52    218.53       NaN
# 2013     274.81       269.32     NaN  274.92  278.03    263.35       NaN
# 2014     283.59       268.17     NaN  273.62  287.70    267.79       NaN
# 2015     315.58       300.44     NaN  294.38  308.94    314.05       NaN
# 2016     394.60       369.82  372.68  348.35  359.55    360.66    368.04
# 2017     393.23       356.34  366.87  346.35  348.79    340.48    352.63
#
#       João Pessoa   Natal  Recife  Salvador
# 2001        96.42   96.39   94.11     91.93
# 2002       108.09  111.98  108.88    107.29
# 2003       131.24  135.60  133.26    136.21
# 2004       137.04  138.72  133.86    135.08
# 2005       136.60  136.96  137.19    132.86
# 2006       135.99  135.63  135.14    136.02
# 2007       143.51  151.69  144.88    146.22
# 2008       180.81  193.87  178.68    180.80
# 2009       179.12  193.87  180.92    195.40
# 2010       189.60  204.84  198.93    204.13
# 2011       201.15  219.49  209.51    207.85
# 2012       226.48  233.69  235.52    218.53
# 2013       269.32  274.92  278.03    263.35
# 2014       268.17  273.62  287.70    267.79
# 2015       300.44  294.38  308.94    314.05
# 2016       369.82  348.35  359.55    360.66
# 2017       356.34  346.35  348.79    340.48
# 2018       344.59  341.10  342.08    327.82
# 2019       378.26  375.14  381.29    365.90
# 2020       429.91  428.74  444.88    429.14

# %%
cesta.index[1:2]
# Out:
# Int64Index([2002], dtype='int64')

# %%
# Descobrindo a variação anual da cesta básica em cada capital analisada

mes_a_mes = []
mes_1 = []
percentual_mes_a_mes = {}

# Calculando todos os resultados e colocando em uma lista
for i in cesta.columns:
    for p in cesta.index[1:]:
        n = ((cesta[i][p] / cesta[i][p-1]) - 1) * 100
        mes_1.append(n)

# Separando a lista pela quantidade de dados e salvando em uma nova lista separada
n = 19
for s in range(0, len(mes_1), 9):    
    mes_a_mes.append(mes_1[s:s + n])
    
# Passando os dados da lista para um dicionário    
for i in range(0, len(cesta.columns)):
    percentual_mes_a_mes[cesta.columns[i]] = mes_a_mes[i]


percentual_mes_a_mes
# Out:
# {'Brasília': [9.373942470389164,
#   23.00433168316833,
#   4.012073952961881,
#   2.8113663845223735,
#   -0.9820640987944773,
#   5.541038128043718,
#   24.326149344437553,
#   0.171992396125642,
#   2.227543827941436,
#   9.317127071823217,
#   7.613310152427943,
#   11.357829876765834,
#   5.766051486217494,
#   14.323082812300614,
#   23.723422065963497,
#   -8.784393324312134,
#   0.7763629620472168,
#   11.015971932579326,
#   6.921699927070213],
#  'Goiânia': [9.317127071823217,
#   7.613310152427943,
#   11.357829876765834,
#   5.766051486217494,
#   14.323082812300614,
#   23.723422065963497,
#   -8.784393324312134,
#   0.7763629620472168,
#   11.015971932579326,
#   6.921699927070213,
#   13.967251923456313,
#   22.459754197680446,
#   4.191108912290598,
#   2.475919142585803,
#   -2.1579400278016747,
#   8.145592314457751,
#   24.73568970910227,
#   2.241837604694341,
#   5.724516825272241],
#  'Belo Horizonte': [6.921699927070213,
#   13.967251923456313,
#   22.459754197680446,
#   4.191108912290598,
#   2.475919142585803,
#   -2.1579400278016747,
#   8.145592314457751,
#   24.73568970910227,
#   2.241837604694341,
#   5.724516825272241,
#   9.715584837377623,
#   5.252251871273317,
#   10.731648519426273,
#   4.796806966618283,
#   12.672252614084911,
#   20.87763505623501,
#   -3.4446817164938026,
#   -3.8440272767963024,
#   14.139809972344697],
#  'Rio de Janeiro': [5.724516825272241,
#   9.715584837377623,
#   5.252251871273317,
#   10.731648519426273,
#   4.796806966618283,
#   12.672252614084911,
#   20.87763505623501,

plt.bar(cesta_evolucao_perc.index,cesta_evolucao_perc['Brasília'].values, color='chocolate')
plt.title('Brasília',loc='center')

plt.subplot(4,4,2)
plt.bar(cesta_evolucao_perc.index,cesta_evolucao_perc['Goiânia'].values, color='chocolate')
plt.title('Goiânia',loc='center')

plt.subplot(4,4,3)
plt.bar(cesta_evolucao_perc.index,cesta_evolucao_perc['Belo Horizonte'].values, color='chocolate')
plt.title('Belo Horizonte',loc='center')

plt.subplot(4,4,4)
plt.bar(cesta_evolucao_perc.index,cesta_evolucao_perc['Rio de Janeiro'].values, color='chocolate')
plt.title('Rio de Janeiro',loc='center')

plt.subplot(4,4,5)
plt.bar(cesta_evolucao_perc.index,cesta_evolucao_perc['São Paulo'].values, color='chocolate')
plt.title('São Paulo',loc='center')

plt.subplot(4,4,6)
plt.bar(cesta_evolucao_perc.index,cesta_evolucao_perc['Vitória'].values, color='chocolate')
plt.title('Vitória',loc='center')

plt.subplot(4,4,7)
plt.bar(cesta_evolucao_perc.index,cesta_evolucao_perc['Curitiba'].values, color='chocolate')
plt.title('Curitiba',loc='center')

plt.subplot(4,4,8)
plt.bar(cesta_evolucao_perc.index,cesta_evolucao_perc['Florianópolis'].values, color='chocolate')
plt.title('Florianópolis',loc='center')

plt.subplot(4,4,9)
plt.bar(cesta_evolucao_perc.index,cesta_evolucao_perc['Porto Alegre'].values, color='chocolate')
plt.title('Porto Alegre',loc='center')

plt.subplot(4,4,10)
plt.bar(cesta_evolucao_perc.index,cesta_evolucao_perc['Belém'].values, color='chocolate')
plt.title('Belém',loc='center')

plt.subplot(4,4,11)
plt.bar(cesta_evolucao_perc.index,cesta_evolucao_perc['Aracaju'].values, color='chocolate')
plt.title('Aracaju',loc='center')

plt.subplot(4,4,12)
plt.bar(cesta_evolucao_perc.index,cesta_evolucao_perc['Fortaleza'].values, color='chocolate')
plt.title('Fortaleza',loc='center')

plt.subplot(4,4,13)
plt.bar(cesta_evolucao_perc.index,cesta_evolucao_perc['João Pessoa'].values, color='chocolate')
plt.title('João Pessoa',loc='center')

plt.subplot(4,4,14)
plt.bar(cesta_evolucao_perc.index,cesta_evolucao_perc['Natal'].values, color='chocolate')
plt.title('Natal',loc='center')

plt.subplot(4,4,15)
plt.bar(cesta_evolucao_perc.index,cesta_evolucao_perc['Recife'].values, color='chocolate')
plt.title('Recife',loc='center')

plt.subplot(4,4,16)
plt.bar(cesta_evolucao_perc.index,cesta_evolucao_perc['Salvador'].values, color='chocolate')
plt.title('Salvador',loc='center')


plt.show()

# %%
# Diferença percentual entre o valor da cesta básica do ano de 2020 em comparação com o valor de 2001

for i in cesta.columns:
    n =  ((cesta[i][2020] / cesta[i][2001]) -1) * 100
    print(f'{i:<15} - {round(n,2):>10}')
# Out:
# Brasília        -     309.31
# Goiânia         -     390.33
# Belo Horizonte  -     313.09
# Rio de Janeiro  -      356.6
# São Paulo       -     341.86
# Vitória         -     388.45
# Curitiba        -      316.8
# Florianópolis   -     369.26
# Porto Alegre    -      325.4
# Belém           -     322.57
# Aracaju         -     300.64
# Fortaleza       -     395.33
# João Pessoa     -     345.87
# Natal           -      344.8
# Recife          -     372.72
# Salvador        -     366.81

# %%
cesta.head(20).T
# Out:
#                   2001    2002    2003    2004    2005    2006    2007  \
# Brasília        118.20  129.28  159.02  165.40  170.05  168.38  177.71
# Goiânia         101.38  115.54  141.49  147.42  151.07  147.81  159.85
# Belo Horizonte  118.88  126.48  152.76  161.64  163.46  166.12  180.43
# Rio de Janeiro  120.54  131.20  157.13  165.69  169.81  168.27  183.99
# São Paulo       126.36  137.47  167.28  172.38  178.75  176.98  193.37
# Vitória         108.25  121.31  142.96  151.83  160.26  157.63  173.61
# Curitiba        121.54  131.84  157.57  161.77  166.65  163.64  175.74
int64Index([2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011,
#             2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020],
#            dtype='int64')

# %%
cesta['Vitória'][[2007,2017]]
# Out:
# 2007    173.61
# 2017    406.35
# Name: Vitória, dtype: float64

# %%
plt.style.use('fivethirtyeight')
cesta[['Vitória','Brasília']].plot(kind='line', figsize=(20,10))
plt.xticks(cesta.index)
plt.show()

# %%
plt.figure(figsize=(28,6))

plt.subplot(1,4,1)
plt.plot(cesta[['Belo Horizonte','Rio de Janeiro','São Paulo','Vitória']], label=['Belo Horizonte','Rio de Janeiro','São Paulo','Vitória'])
plt.xticks([2002, 2004, 2006, 2008, 2010, 2012, 2014, 2016, 2018, 2020], rotation=90)
plt.title('Região Sudeste')
plt.legend()

plt.subplot(1,4,2)
plt.plot(cesta[['Curitiba','Florianópolis','Porto Alegre']], label=['Curitiba','Florianópolis','Porto Alegre'])
plt.xticks([2002, 2004, 2006, 2008, 2010, 2012, 2014, 2016, 2018, 2020], rotation=90)
plt.title('Região Sul')
plt.legend()

plt.subplot(1,4,3)
plt.plot(cesta[['Brasília','Goiânia']], label=['Brasília','Goiânia'])
plt.xticks([2002, 2004, 2006, 2008, 2010, 2012, 2014, 2016, 2018, 2020], rotation=90)
plt.title('Região Centroeste')
plt.legend()

plt.subplot(1,4,4)
plt.plot(cesta[['Aracaju','Fortaleza','João Pessoa','Natal','Recife','Salvador']], label=['Aracaju','Fortaleza','João Pessoa','Natal','Recife','Salvador'])
plt.xticks([2002, 2004, 2006, 2008, 2010, 2012, 2014, 2016, 2018, 2020], rotation=90)
plt.title('Região Nordeste')
plt.legend()

plt.show()

# %%
plt.style.use('fivethirtyeight')

ax = cesta[['São Paulo','Vitória', 'Brasília', 'Goiânia', 'Salvador', 'Aracaju']].plot(rot=0, kind='bar', figsize=(30,8), width=0.7)

plt.show()

# %%
plt.style.use('fivethirtyeight')

media = (cesta['São Paulo'] + cesta['Vitória'] + cesta['Brasília'] + cesta['Goiânia'] + cesta['Salvador'] + cesta['Aracaju'])/6

fig = plt.subplots(figsize=(30,8))

plt.bar(cesta.index-0.30, cesta['São Paulo'],width=0.12, alpha=0.8)
plt.bar(cesta.index-0.18, cesta['Vitória'],width=0.12,color='orange' ,alpha=0.8)
plt.bar(cesta.index-0.06, cesta['Brasília'],width=0.12,alpha=0.8)
plt.bar(cesta.index+0.06, cesta['Goiânia'],width=0.12,alpha=0.8)
plt.bar(cesta.index+0.18, cesta['Salvador'],width=0.12,alpha=0.8)
plt.bar(cesta.index+0.30, cesta['Aracaju'],width=0.12,alpha=0.8)

plt.xticks(cesta.index, labels=cesta.index)

plt.plot(media.index, media, color='r')

plt.legend(['Média','São Paulo', 'Vitória', 'Brasília', 'Goiânia', 'Salvador','Aracaju'])

plt.show()

# %%
cesta.loc[2015].sort_values(ascending=[False])
# Out:
# São Paulo         389.15
# Porto Alegre      381.13
# Florianópolis     378.69
# Rio de Janeiro    370.27
# Vitória           367.32
# Brasília          358.38
# Curitiba          357.98
# Belo Horizonte    346.99
# Belém             329.61
# Goiânia           325.42
# Fortaleza         315.58
# Salvador          314.05
# Recife            308.94
# João Pessoa       300.44
# Natal             294.38
# Aracaju           279.76
# Name: 2015, dtype: float64

# %%
cesta.describe()
# Out:
#          Brasília     Goiânia  Belo Horizonte  Rio de Janeiro   São Paulo  \
# count   20.000000   20.000000        20.00000        20.00000   20.000000
# mean   271.501500  250.543500       265.49650       282.64400  293.730000
# std    116.664629  113.393169       109.82441       129.45354  129.974793
# min    118.200000  101.380000       118.88000       120.54000  126.360000
# 25%    169.632500  150.255000       165.45500       169.42500  178.307500
# 50%    236.790000  226.000000       237.89000       242.17500  258.235000
# 75%    369.897500  335.367500       354.27500       383.97000  400.580000
# max    483.810000  497.100000       491.08000       550.38000  558.330000
#
#           Vitória    Curitiba  Florianópolis  Porto Alegre     Belém  \
# count   20.000000   20.000000      20.000000     20.000000   20.0000
# mean   273.964000  268.002000     280.821500    291.933500  252.3635
# std    126.033536  114.701248     130.575342    125.525564  108.2971
# min    108.250000  121.540000     115.720000    126.520000  106.6100
# 25%    159.602500  165.897500     164.402500    177.390000  152.1050
# 50%    243.615000  236.085000     242.605000    257.870000  225.2700
# 75%    377.077500  366.025000     391.882500    396.102500  339.4150
# max    528.750000  506.580000     543.030000    538.210000  450.5000
#
#           Aracaju   Fortaleza  João Pessoa       Natal      Recife    Salvador
# count   20.000000   20.000000     20.00000   20.000000   20.000000   20.000000
# mean   221.090000  241.751500    229.14500  231.766500  232.107000  228.075500
# std     96.590384  119.388196    103.15179   98.552564  104.466218   99.638027
# min    102.270000   96.920000     96.42000   96.390000   94.110000   91.930000
# 25%    142.015000  135.270000    136.93000  138.280000  136.677500  136.162500
# 50%    182.730000  199.765000    195.37500  212.165000  204.220000  205.990000
# 75%    296.397500  333.682500    311.47750  306.060000  317.225000  317.492500
# max    409.730000  480.070000    429.91000  428.740000  444.880000  429.140000

# %%
# Criando duas funções para descobrir os valores máximos e mínimos da cesta básica em cada ano observado, e salvando a diferença do valor em uma lista

city_high = []
value_high = []
city_low = []
value_low = []
difference = []

def maximum(year):
    maior = cesta.loc[year].idxmax()
    return maior

def minimum(year):
    cesta1 = cesta.loc[[year]]
    for i in cesta.columns:
        if float(cesta1[i]) == 0:
            cesta1 = cesta1.drop(columns=[i])
    menor = cesta1.loc[year].idxmin()
    return menor

print(f'{"Data"}  -  {"Cidade mais cara":.<10}{"Valor":>11}     {"Cidade mais barata":.<12}{"Valor":>9}\n')

for i in cesta.index:
    city_high.append(maximum(i))
    value_high.append(cesta[maximum(i)][i])
    city_low.append(minimum(i))
    value_low.append(cesta[minimum(i)][i])
    difference.append(cesta[maximum(i)][i] - cesta[minimum(i)][i])

    print(f'{i}  -  {maximum(i):.<18}{cesta[maximum(i)][i]:.>10.2f}    {minimum(i):.<18}{cesta[minimum(i)][i]:.>10.2f}' )
# Out:
# Data  -  Cidade mais cara      Valor     Cidade mais barata    Valor
#
# 2001  -  Porto Alegre..........126.52    Salvador...............91.93
# 2002  -  Porto Alegre..........141.39    Salvador..............107.29
# 2003  -  Porto Alegre..........168.61    João Pessoa...........131.24
# 2004  -  Porto Alegre..........176.13    Recife................133.86
# 2005  -  São Paulo.............178.75    Salvador..............132.86
# 2006  -  São Paulo.............176.98    Fortaleza.............130.27
# 2007  -  Porto Alegre..........199.69    João Pessoa...........143.51
# 2008  -  São Paulo.............235.87    Recife................178.68
# 2009  -  Porto Alegre..........243.12    Aracaju...............171.03
# 2010  -  Porto Alegre..........248.10    Aracaju...............177.86
# 2011  -  São Paulo.............268.57    Aracaju...............185.30
# 2012  -  São Paulo.............292.84    Aracaju...............200.42
# 2013  -  São Paulo.............328.43    Aracaju...............233.66
# 2014  -  São Paulo.............344.90    Aracaju...............234.72
# 2015  -  São Paulo.............389.15    Aracaju...............279.76
# 2016  -  São Paulo.............456.48    Natal.................348.35
# 2017  -  Porto Alegre..........445.72    Salvador..............340.48
# 2018  -  São Paulo.............444.49    Salvador..............327.82
# 2019  -  São Paulo.............490.36    Aracaju...............362.23
# 2020  -  São Paulo.............558.33    Aracaju...............409.73

# %%
difference
# Out:
# [34.58999999999999,
#  34.09999999999998,
#  37.370000000000005,
#  42.26999999999998,
#  45.889999999999986,
#  46.70999999999998,
#  56.18000000000001,
#  57.19,
#  72.09,
#  70.23999999999998,
#  83.26999999999998,
#  92.41999999999999,
#  94.77000000000001,
#  110.17999999999998,
#  109.38999999999999,
#  108.13,
#  105.24000000000001,
#  116.67000000000002,
#  128.13,
#  148.60000000000002]

# %%
# Gráfico com valores anuais da cesta básica da cidade mais cara e mais barata entre 2001 e 2020

plt.style.use('fivethirtyeight')

fig, ax = plt.subplots(figsize=(26,8))

p1 = ax.bar(cesta.index,value_high, label='Cidades mais caras')
p2 = ax.bar(cesta.index,value_low, label='Cidades mais baratas')


ax.bar_label(p1, label_type='edge', fontsize=14)
ax.bar_label(p2, label_type='center', fontsize=14)
ax.legend(fontsize=16)

ax.set_xticks(cesta.index, labels=[2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020])

#plt.text(value_high[0], ha = 'center', bbox = dict(facecolor ='cyan', alpha =0.8))

#plt.xticks(np.arange(min(cesta.index), max(cesta.index)+1, 1.0))

plt.show()

# %%
# Diferença percentual entre o valor da cesta básica mais cara e mais barata entre as cidades entre 2001 e 2020, e salvando os dados em uma lista

percentual_maior_menor = []

print('Data    Cidade mais cara      Cidade Mais Barata      Diferença percentual')

for i in range(len(value_high)):
    perc = round((((value_high[i] / value_low[i]) -1) * 100),2)
    percentual_maior_menor.append(perc)
    print(f'{cesta.index[i]:<10}{city_high[i]:<25}{city_low[i]:<22}{perc:>8}%')

#percentual_maior_menor
# Out:
# Data    Cidade mais cara      Cidade Mais Barata      Diferença percentual
# 2001      Porto Alegre             Salvador                 37.63%
# 2002      Porto Alegre             Salvador                 31.78%
# 2003      Porto Alegre             João Pessoa              28.47%
# 2004      Porto Alegre             Recife                   31.58%
# 2005      São Paulo                Salvador                 34.54%
# 2006      São Paulo                Fortaleza                35.86%
# 2007      Porto Alegre             João Pessoa              39.15%
# 2008      São Paulo                Recife                   32.01%
# 2009      Porto Alegre             Aracaju                  42.15%
# 2010      Porto Alegre             Aracaju                  39.49%
# 2011      São Paulo                Aracaju                  44.94%
# 2012      São Paulo                Aracaju                  46.11%
# 2013      São Paulo                Aracaju                  40.56%
# 2014      São Paulo                Aracaju                  46.94%
# 2015      São Paulo                Aracaju                   39.1%
# 2016      São Paulo                Natal                    31.04%
# 2017      Porto Alegre             Salvador                 30.91%
# 2018      São Paulo                Salvador                 35.59%
# 2019      São Paulo                Aracaju                  35.37%
# 2020      São Paulo                Aracaju                  36.27%

# %%
# Gráfico que mostra a diferença percentual entre o valor da cesta básica na cidade mais cara e mais barata entre 2001 e 2020

plt.style.use('fivethirtyeight')

fig, ax = plt.subplots(figsize=(20,14))

index = [0, 10, 20, 30, 40, 50]

p = ax.barh(cesta.index, percentual_maior_menor, label='Cidades mais caras') #color=['#FFE4B5', '#FFDEAD', '#FFDAB9', '#FFE4C4', '#FFEBCD', '#FFEFD5','#FAEBD7', '#FAF0E6', '#FDF5E6', '#FFFAF0'])

ax.bar_label(p, label_type='edge', fontsize=18, bbox = dict(facecolor = 'cyan', alpha =0.8))

ax.set_yticks(cesta.index, labels=[2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020])
ax.set_xticks(index, labels=[0, 10, 20, 30, 40, 50])

ax.set_title('Diferença percentual entre a cesta básica mais cara e mais barata no período', fontsize=25, weight='semibold', pad=20)

ax.set_xlabel('Diferença Percentual', fontsize=20)
ax.set_ylabel('Ano', fontsize=20)

plt.show()

# %%
# Descobrindo a média anual do valor da cesta básica entre todas as capitais brasileiras entre 2001 e 2020

dict_media_anual = {}

for p in cesta.index:
    count = 0
    for i in cesta.loc[p]:
        if i > 0:
            count += 1

    media_anual = round(((sum(cesta.loc[p])) / count), 2)
    dict_media_anual[p] = media_anual

dict_media_anual
# Out:
# {2001: 108.88,
#  2002: 121.7,
#  2003: 147.32,
#  2004: 151.91,
#  2005: 154.29,
#  2006: 153.05,
#  2007: 166.84,
#  2008: 205.6,
#  2009: 206.26,
#  2010: 216.17,
#  2011: 234.53,
#  2012: 254.6,
#  2013: 289.87,
#  2014: 303.29,
#  2015: 338.63,
#  2016: 406.24,
#  2017: 388.52,
#  2018: 386.19,
#  2019: 424.15,
#  2020: 485.64}

# %%
# Criando um dataframe com a média anual do valor da cesta básica entre as capitais brasileiras entre 2001 e 2020

cesta_basica = pd.DataFrame(dict_media_anual.values(), index=[2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020], columns=['Mean'])

cesta_basica
# Out:
#         Mean
# 2001  108.88
# 2002  121.70
# 2003  147.32
# 2004  151.91
# 2005  154.29
# 2006  153.05
# 2007  166.84
# 2008  205.60
# 2009  206.26
# 2010  216.17
# 2011  234.53
# 2012  254.60
# 2013  289.87
# 2014  303.29
# 2015  338.63
# 2016  406.24
# 2017  388.52
# 2018  386.19
# 2019  424.15
# 2020  485.64

# %%
# Gráfico que mostra a evolução da média anual do valor da cesta básica entre as capitais brasileiras entre 2001 e 2020

plt.style.use('fivethirtyeight')

fig, ax = plt.subplots(figsize=(20,12))

p1 = ax.bar(cesta_basica.index, cesta_basica['Mean'], width=0.5)
p2 = ax.plot(cesta_basica.index, cesta_basica['Mean'], color='r')

ax.bar_label(p1, fontsize=12, padding=10, color='black')

ax.set_xticks(cesta_basica.index, labels=cesta_basica.index)

plt.show()

# %%
plt.style.use('fivethirtyeight')

fig, ax = plt.subplots(figsize=(20,12))

#plt.grid(axis='y', zorder=1)

ax = plt.bar(cesta_basica.index, cesta_basica['Mean'], width=0.5, zorder=2)
ax2 = plt.plot(cesta_basica.index, cesta_basica['Mean'], color='red', zorder=2)

plt.bar_label(p1, fontsize=12, padding=10, color='black')

plt.xticks(np.arange(min(cesta_basica.index), max(cesta_basica.index)+1, 1.0))

plt.show()

# %%
# Obtendo a media por ano de maneira fácil com numpy (contando os zeros)
round(cesta.mean(axis=1),2)
# Out:
# 2001    108.88
# 2002    121.70
# 2003    147.32
# 2004    151.91
# 2005    154.29
# 2006    153.05
# 2007    166.84
# 2008    205.60
# 2009    206.26
# 2010    216.17
# 2011    234.53
# 2012    254.60
# 2013    289.87
# 2014    303.29
# 2015    338.63
# 2016    406.24
# 2017    388.52
# 2018    386.19
# 2019    424.15
# 2020    485.64
# dtype: float64
